# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import os
workspace_folder = "/content/drive/My Drive/Barbados_Forecasting_Tool/Forecaster"
os.chdir(workspace_folder)
print("Current Working Directory:", os.getcwd())

# !ls -lh
# Out:
# Current Working Directory: /content/drive/.shortcut-targets-by-id/1ihWNkxWXqnMyzL5OzM40D3c6Qr0-vMEp/Barbados_Forecasting_Tool/Forecaster
# total 1.7M
# -rw------- 1 root root 204K Mar 23 18:11 Forecaster_Test.ipynb
# -rw------- 1 root root  70K Mar 28 18:16 Forecaster_Trainer.ipynb
# -rw------- 1 root root 294K Mar 23 18:11 Forecaster_Validation.ipynb
# -rw------- 1 root root    0 Mar 23 18:11 __init__.py
# drwx------ 2 root root 4.0K Mar 23 18:15 __pycache__
# -rw------- 1 root root  447 Mar 27 15:50 requirements.txt
# -rw------- 1 root root 1.1M Mar 23 18:11 Trainer.ipynb
# -rw------- 1 root root 9.0K Mar 23 18:11 weather_utils.py

# %%
# !ls -lh
# Out:
# total 1.7M
# -rw------- 1 root root 204K Mar 23 18:11 Forecaster_Test.ipynb
# -rw------- 1 root root  70K Mar 28 18:16 Forecaster_Trainer.ipynb
# -rw------- 1 root root 294K Mar 23 18:11 Forecaster_Validation.ipynb
# -rw------- 1 root root    0 Mar 23 18:11 __init__.py
# drwx------ 2 root root 4.0K Mar 23 18:15 __pycache__
# -rw------- 1 root root  447 Mar 27 15:50 requirements.txt
# -rw------- 1 root root 1.1M Mar 23 18:11 Trainer.ipynb
# -rw------- 1 root root 9.0K Mar 23 18:11 weather_utils.py

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: padasip in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: sktime in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (0.36.0)
# Requirement already satisfied: weather-utils in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: itables in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (2.2.5)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (5.24.1)
# Requirement already satisfied: retry_requests in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: requests_cache in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (1.2.1)
# Requirement already satisfied: openmeteo_requests in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm->-r requirements.txt (line 1)) (1.14.1)
# Requirement already satisfied: joblib<1.5,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from sktime->-r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from sktime->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in /usr/local/lib/python3.11/dist-packages (from sktime->-r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: scikit-base<0.13.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from sktime->-r requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: scikit-learn<1.7.0,>=0.24 in /usr/local/lib/python3.11/dist-packages (from sktime->-r requirements.txt (line 3)) (1.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from weather-utils->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.11/dist-packages (from weather-utils->-r requirements.txt (line 4)) (1.37.22)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from weather-utils->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from itables->-r requirements.txt (line 5)) (7.34.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->-r requirements.txt (line 6)) (9.0.0)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.11/dist-packages (from retry_requests->-r requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests_cache->-r requirements.txt (line 8)) (25.3.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests_cache->-r requirements.txt (line 8)) (24.1.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests_cache->-r requirements.txt (line 8)) (4.3.7)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.11/dist-packages (from requests_cache->-r requirements.txt (line 8)) (1.4.3)
# Requirement already satisfied: openmeteo-sdk>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openmeteo_requests->-r requirements.txt (line 9)) (1.19.0)
# Requirement already satisfied: flatbuffers==25.2.10 in /usr/local/lib/python3.11/dist-packages (from openmeteo-sdk>=1.4.0->openmeteo_requests->-r requirements.txt (line 9)) (25.2.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1->sktime->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1->sktime->-r requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1->sktime->-r requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->weather-utils->-r requirements.txt (line 4)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->weather-utils->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->weather-utils->-r requirements.txt (line 4)) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.7.0,>=0.24->sktime->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from url-normalize>=1.4->requests_cache->-r requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: botocore<1.38.0,>=1.37.22 in /usr/local/lib/python3.11/dist-packages (from boto3->weather-utils->-r requirements.txt (line 4)) (1.37.22)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3->weather-utils->-r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3->weather-utils->-r requirements.txt (line 4)) (0.11.4)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->itables->-r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->itables->-r requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->itables->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->itables->-r requirements.txt (line 5)) (0.2.13)

# %%
import pytz
from datetime import datetime
import pandas as pd
import numpy as np
import os
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import keras
import pandas as pd
from itables import show
from keras.models import Sequential # type: ignore
from keras.layers import Dense, Input, LSTM, Embedding, SimpleRNN, GRU, Bidirectional, Conv1D, MaxPooling1D, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.models import load_model
from keras.metrics import MeanSquaredError, MeanAbsoluteError, RootMeanSquaredError
from keras.regularizers import l2
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, mean_absolute_percentage_error
import scipy
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sktime.transformations.series.holiday import HolidayFeatures
from holidays import country_holidays, financial_holidays
from sklearn.multioutput import MultiOutputRegressor
from lightgbm import LGBMRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from padasip.filters import FilterRLS
import pickle
from sklearn.model_selection import TimeSeriesSplit
np.printoptions(suppress=True)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
from weather_utils import WeatherUtils
import seaborn as sns
import holidays
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 1000)

# %%
class ForecasterUtils:
    def get_barbados_holidays_list(self, years):
        barbados_holidays_list = holidays.Barbados(years=years)
        barbados_holidays_df = pd.DataFrame(barbados_holidays_list.values(), index=pd.to_datetime(list(barbados_holidays_list.keys())))
        return barbados_holidays_df

    def remove_first_and_last_days(self, raw_data):
        raw_data = raw_data.copy()
        first_day = raw_data.index[0].strftime("%Y-%m-%d")
        last_day = raw_data.index[-1].strftime("%Y-%m-%d")

        raw_data = raw_data.drop(raw_data.loc[first_day].index)
        raw_data = raw_data.drop(raw_data.loc[last_day].index)

        return raw_data

    def remove_last_day(self, raw_data):
        raw_data = raw_data.copy()
        # first_day = raw_data.index[0].strftime("%Y-%m-%d")
        last_day = raw_data.index[-1].strftime("%Y-%m-%d")

        # raw_data = raw_data.drop(raw_data.loc[first_day].index)
        raw_data = raw_data.drop(raw_data.loc[last_day].index)

        return raw_data

    def add_extra_hour_in_beginning(self, raw_data):
        raw_data = raw_data.copy()
        first_index = raw_data.index[0]
        hour_before_first_index = first_index - pd.Timedelta(hours=1)
        hour_before_first_index = pd.Timestamp(hour_before_first_index)
        raw_data.loc[hour_before_first_index] = raw_data.loc[first_index]
        raw_data = raw_data.sort_index()

        return raw_data

    def remove_incomplete_days(self, raw_data):
        raw_data = raw_data.copy()
        grouped_raw_data = raw_data.groupby(by=raw_data.index.date).count()
        incomplete_days = grouped_raw_data[grouped_raw_data != 24].index
        raw_data = self.remove_dates_from_raw_data(raw_data, incomplete_days, "Removing Incomplete Days")

        return raw_data

    # This function assumes that the incoming raw data has a datetime index
    def preprocess_raw_data(self, data, column_name, threshold):
        data = data.copy()
        data = self.add_extra_hour_in_beginning(data)
        data = data.resample(rule="h", closed="left", label="right").mean()
        data = self.remove_last_day(data)
        data = data[column_name]
        filtered_data, nan_values_filtered = self.remove_nan_days_above_threshold(threshold, data)
        filtered_data = filtered_data.interpolate(method="time")
        filtered_data = self.remove_incomplete_days(filtered_data)

        return filtered_data

    def remove_dates_from_raw_data(self, raw_data, dates, comment):
        print(f"{comment} - Total Dropped Days: ", len(dates))
        filtered_data = raw_data.copy()

        for date in dates:
            date = date.strftime("%Y-%m-%d")
            filtered_data = filtered_data.drop(filtered_data.loc[date].index)

        return filtered_data

    def remove_nan_days_above_threshold(self, threshold, raw_data):
        nan_values = raw_data[raw_data.isna()].fillna(0)
        nan_values = nan_values.groupby(by=nan_values.index.date).count()
        nan_values.index = pd.to_datetime(nan_values.index)
        nan_values_filtered = nan_values[nan_values > threshold]
        filtered_data = self.remove_dates_from_raw_data(raw_data, nan_values_filtered.index, "Removing Nan Values")

        return filtered_data, nan_values_filtered

    def remove_space_in_column_names(self, data):
        data.columns = data.columns.str.replace(" ", "_")
        return data

    def get_raw_data_from_path(self, filepath):
        raw_data = pd.read_csv(
            filepath,
            na_values=[""],
            skipinitialspace=True,
            index_col="Time",
            parse_dates=True,
        ).dropna()

        raw_data.index = pd.to_datetime(raw_data.index).tz_localize(None)
        raw_data = raw_data[~raw_data.index.duplicated(keep="last")]

        return raw_data

    def minmax_scale(self, data, min, max):
        range_val = max - min

        if (range_val == 0).any():
            range_val[range_val == 0] = 1

        return (data - min) / range_val

    def minmax_inverse_scale(self, data, min, max):
        range_val = max - min

        return data * range_val + min

    def get_unique_dates_from_hourly_data(self, data):
        return pd.to_datetime(data.index.date).unique()

    # def get_one_hot_day_of_week(self, dates_index):
    #     day_of_week = pd.get_dummies(dates_index.dayofweek).astype(int)
    #     day_of_week.index = dates_index
    #     print(day_of_week)
    #     day_of_week.columns = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
    #     return day_of_week

    def get_one_hot_day_of_week(self, dates_index):
        all_days = np.arange(7)
        dates_index = pd.to_datetime(dates_index)
        day_of_week = dates_index.dayofweek
        one_hot_encoded = pd.DataFrame(0, index=dates_index, columns=all_days)

        for index, day in zip(dates_index, day_of_week):
            # print(index, day)
            one_hot_encoded.loc[index, day] = 1

        one_hot_encoded.columns=["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
        return one_hot_encoded

    def add_is_holiday_column_to_one_hot_day_of_week(self, day_of_week, holidays_df):
        day_of_week["is_holiday"] = day_of_week.index.isin(holidays_df.index).astype(int)
        return day_of_week

    def reshape_X_to_LSTM_shape(self, X):
        return X.reshape(X.shape[0], 1, X.shape[1])

    def create_X_y(self, data, target_column, hours_in_day, day_of_week):
        X = []
        y_bl = []
        y_cl = []

        prev_dates = []
        cur_dates = []

        print("Hours: ", hours_in_day)
        print("Daytime Flag: ", self.daytime_flag)
        print("Hours in day: ", self.hours_in_day)

        for i in range(hours_in_day, len(data), hours_in_day):
            cur = i
            prev = i - hours_in_day
            print(data.index[i])

            if data.index[cur] != (data.index[prev] + pd.Timedelta(days=1)):
                print(
                    f"ALERT: Current: {data.index[cur]} to {data.index[cur + hours_in_day - 1]}, Previous: {data.index[prev]} to {data.index[prev + hours_in_day - 1]}"
                )
                print("ALERT: Day Change Detected")
                continue

            print(
                    f"ALERT: Current: {data.index[cur]} to {data.index[cur + hours_in_day - 1]}, Previous: {data.index[prev]} to {data.index[prev + hours_in_day - 1]}"
                )

            prev_historic_temp = data["temperature_2m_historic"].iloc[prev:cur].values.flatten()
            # prev_forecasted_temp = data["temperature_2m_forecast"][prev:cur].values.flatten()
            prev_historic_shortwave_radiation = data["shortwave_radiation_historic"].iloc[prev:cur].values.flatten()
            # prev_forecasted_shortwave_radiation = data["shortwave_radiation_forecast"][prev:cur].values.flatten()
            prev_load_demand = data[target_column].iloc[prev:cur].values.flatten()
            prev_historic_cloud_cover = data["cloud_cover_historic"].iloc[prev:cur].values.flatten()

            # cur_historic_temp = data["temperature_2m_historic"].iloc[cur : cur + hours_in_day].values.flatten()
            cur_forecasted_temp = data["temperature_2m_forecast"].iloc[cur : cur + hours_in_day].values.flatten()
            # cur_historic_shortwave_radiation = data["shortwave_radiation_historic"].iloc[cur : cur + hours_in_day].values.flatten()
            cur_forecasted_shortwave_radiation = data["shortwave_radiation_forecast"].iloc[cur : cur + hours_in_day].values.flatten()
            cur_forecasted_cloud_cover = data["cloud_cover_forecast"].iloc[cur : cur + hours_in_day].values.flatten()
            cur_load_demand = data[target_column].iloc[cur : cur + hours_in_day].values.flatten()
            cur_day_of_week = day_of_week.iloc[cur // hours_in_day].values.flatten()

            X_day = np.hstack(
                [
                    prev_load_demand,
                    prev_historic_temp,
                    # prev_forecasted_temp,
                    # cur_historic_temp,
                    cur_forecasted_temp,
                    prev_historic_shortwave_radiation,
                    # prev_forecasted_shortwave_radiation,
                    # cur_historic_shortwave_radiation,
                    cur_forecasted_shortwave_radiation,
                    prev_historic_cloud_cover,
                    cur_forecasted_cloud_cover,
                    cur_day_of_week,
                ]
            )
            y_day_bl = cur_load_demand
            y_day_cl = cur_load_demand - prev_load_demand

            X.append(X_day)
            y_bl.append(y_day_bl)
            y_cl.append(y_day_cl)

            prev_day_date = data.index[prev:cur].values.flatten()
            cur_day_date = data.index[cur : cur + hours_in_day].values.flatten()

            prev_dates.append(prev_day_date)
            cur_dates.append(cur_day_date)

        X = np.array(X)
        X_LSTM = self.reshape_X_to_LSTM_shape(X)
        y_bl = np.array(y_bl)
        y_cl = np.array(y_cl)

        cur_dates = np.array(cur_dates)
        prev_dates = np.array(prev_dates)

        return X, X_LSTM, y_bl, y_cl, cur_dates, prev_dates

    def convert_cl_to_bl(self, y_pred_cl, y, X, hours_in_day):
        y_prev_bl = X[:, :hours_in_day]
        # y_pred_cl_bl = []

        print(y_prev_bl.shape, y_pred_cl.shape)

        if y_prev_bl.shape == y_pred_cl.shape:
            y_pred_cl_bl = y_pred_cl + y_prev_bl

        return y_pred_cl_bl

    # callbacks=[EarlyStopping(patience=50), ReduceLROnPlateau(patience=20, factor=0.1, min_lr=0.000000001)]

    def predict_model(self, model, X):
        y_pred = model.predict(X)
        return y_pred

    def get_trained_model_keras(self, path, model_type, feeder_filesave_name):
        model_save_path = f"{path}/{model_type}/{feeder_filesave_name}.keras"
        model = load_model(model_save_path)

        return model

    def get_trained_model(self, path, model_type, feeder_filesave_name):
        model_save_path = f"{path}/{model_type}/{feeder_filesave_name}.pkl"
        model = pickle.load(open(model_save_path, 'rb'))

        return model

    def get_train_stats(self, train_stats_path, feeder_filesave_name):
        train_stats_file_path = f"{train_stats_path}/{feeder_filesave_name}_train_stats.csv"
        train_stats = pd.read_csv(train_stats_file_path, index_col=0)

        return train_stats

    def adapt_rls_combiner_and_predict(self, results, hours, rls_combiner=None, adapt=True):
        rls_preds = []
        samples = results.shape[0]
        # hours = y.shape[1]

        if not rls_combiner:
            print("Building a new RLS Combiner")
            rls_combiner = [FilterRLS(n=results.shape[1] - 1, mu=0.99) for _ in range(hours)]

        for i in range(0, samples, hours):
            for j in range(hours):
                rls_train_sample = [results.iloc[i][col] for col in results.columns[1:]]
                rls_train_sample = np.array(rls_train_sample).reshape(-1)
                rls_actual_sample = results.iloc[i, 0]

                rls_preds_sample = rls_combiner[j].predict(rls_train_sample)
                if adapt:
                    rls_combiner[j].adapt(rls_actual_sample, rls_train_sample)
                    rls_preds.append(rls_preds_sample)

        results["RLS"] = rls_preds
        return results, rls_combiner

    def build_rls_combiner(self, hours_in_day, n_preds):
        return [FilterRLS(n=n_preds, mu=0.99) for _ in range(hours_in_day)]

    def adapt_and_predict_rls_combiner(self, actual, pred_1, pred_2, hours_in_day, rls_combiner=None):
        if not rls_combiner:
            rls_combiner = self.build_rls_combiner(hours_in_day, 2)

        samples = actual.shape[0]
        rls_preds = []

        for i in range(samples):
            for j in range(hours_in_day):
                rls_train_sample = [pred_1[i, j], pred_2[i, j]]
                rls_train_sample = np.array(rls_train_sample).reshape(-1)
                rls_actual_sample = actual[i, j]

                rls_preds_sample = rls_combiner[j].predict(rls_train_sample)
                rls_combiner[j].adapt(rls_actual_sample, rls_train_sample)
                rls_preds.append(rls_preds_sample)

                # i += 1

        rls_preds = np.array(rls_preds).reshape(samples, hours_in_day)

        return rls_preds, rls_combiner

    def smape_metric(self, y_true, y_pred):
        return 100 * np.mean(2 * np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))

    def get_metrics(self, results):
        results = results.copy()
        actual = results["Actual"]
        preds = results.drop(columns=["Actual"])

        smape = preds.apply(lambda x: self.smape_metric(actual, x))
        mae = preds.apply(lambda x: mean_absolute_error(actual, x))
        rmse = preds.apply(lambda x: root_mean_squared_error(actual, x))

        metrics = pd.DataFrame({"SMAPE": smape, "MAE": mae, "RMSE": rmse})

        return metrics

    def train_ann_model(self, X_train, y_train, epochs=10, callbacks=None):
        model = Sequential()
        model.add(Input(shape=(X_train.shape[1],)))
        model.add(Dense(46, activation='sigmoid'))
        model.add(Dense(y_train.shape[1], activation='linear'))

        model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=[MeanAbsoluteError(), RootMeanSquaredError()])
        model.summary()

        model.fit(X_train, y_train, epochs=epochs, batch_size=32, callbacks=callbacks, shuffle=False)

        return model

    def train_lstm_model(self, X_train_LSTM, y_train, epochs=10, callbacks=None):
        model = Sequential()
        model.add(Input(shape=(X_train_LSTM.shape[1], X_train_LSTM.shape[2])))
        model.add(LSTM(150, return_sequences=False))
        model.add(Dense(y_train.shape[1], activation='linear'))

        model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=[MeanAbsoluteError(), RootMeanSquaredError()])
        model.summary()

        model.fit(X_train_LSTM, y_train, epochs=epochs, batch_size=1, callbacks=callbacks, shuffle=False)

        return model

    def train_benchmark_model(self, X_train, y_train, callbacks=None):
        model = MultiOutputRegressor(LGBMRegressor(verbose=-1))
        model.fit(X_train, y_train)

        return model

    def save_trained_model_keras(self, model, path, model_type, feeder_filesave_name):
        model_save_path = f'{path}/{model_type}/{feeder_filesave_name}.keras'
        os.makedirs(f'{path}/{model_type}', exist_ok=True)
        model.save(model_save_path)

        return

    def save_trained_model(self, model, path, model_type, feeder_filesave_name):
        model_save_path = f'{path}/{model_type}/{feeder_filesave_name}.pkl'
        os.makedirs(f'{path}/{model_type}', exist_ok=True)
        pickle.dump(model, open(model_save_path, 'wb'))

    def save_rls_combiner(self, rls_combiner, model_type, path, feeder_filesave_name):
        rls_combiner_path = f'{path}/{model_type}/{feeder_filesave_name}.pkl'
        os.makedirs(f'{path}/{model_type}', exist_ok=True)

        with open(rls_combiner_path, 'wb') as f:
            pickle.dump(rls_combiner, f)

        return

    def get_saved_rls_combiner(self, path, model_type, feeder_filesave_name):
        with open(f'{path}/{model_type}/{feeder_filesave_name}.pkl', 'rb') as f:
            rls_combiner = pickle.load(f)

        return rls_combiner

    def save_results(self, results, path, feeder_filesave_name, is_validation=False):
        results = results.round(2)
        os.makedirs(path, exist_ok=True)
        if is_validation:
            results.to_csv(f"{path}/{feeder_filesave_name}_Validation_Results.csv")
        else:
            results.to_csv(f"{path}/{feeder_filesave_name}_Test_Results.csv")

    def save_metrics(self, metrics, path, feeder_filesave_name, is_validation=False):
        metrics = metrics.round(2)
        os.makedirs(path, exist_ok=True)
        if is_validation:
            metrics.to_csv(f"{path}/{feeder_filesave_name}_Validation_Metrics.csv")
        else:
            metrics.to_csv(f"{path}/{feeder_filesave_name}_Test_Metrics.csv")

    # def day_ahead_forecast_feeders_data_from_trained_models(self, start_date, end_date, is_validation=False):
    #     prev_date = pd.to_datetime(start_date) - pd.Timedelta(days=1)
    #     prev_date = prev_date.strftime("%Y-%m-%d")
    #     feeders_metadata = pd.read_csv(self.feeders_metadata_path)
    #     weather_utils = WeatherUtils()
    #     feeders_root_path = self.feeders_root_path
    #     saved_models_path = self.saved_models_path
    #     train_stats_path = self.train_stats_path
    #     hours_in_day = self.hours_in_day
    #     target_column = self.target_column
    #     barbados_holidays_df = self.barbados_holidays_df
    #     threshold = self.threshold

    #     for i in range(9, feeders_metadata.shape[0] - 2):
    #         feeder_metadata = feeders_metadata.iloc[i]
    #         feeder_name = feeder_metadata["FeederName"]
    #         feeder_data_filename = feeder_metadata["FileName"]
    #         feeder_filesave_name = feeder_metadata["FileSaveName"]
    #         feeder_data_path = feeders_root_path + feeder_data_filename
    #         feeder_data = self.get_raw_data_from_path(feeder_data_path)
    #         net_load_demand = self.preprocess_raw_data(feeder_data, "NetLoadDemand", threshold)
    #         latitude = feeder_metadata["Latitude"]
    #         longitude = feeder_metadata["Longitude"]

    #         print("========================================")
    #         print(feeder_name)
    #         print("========================================")

    #         historic_weather_data = weather_utils.fetch_historic_data_from_api(latitude, longitude, prev_date, end_date)
    #         forecast_weather_data = weather_utils.fetch_forecast_data_from_api(latitude, longitude, prev_date, end_date)

    #         temperature_historic = historic_weather_data["temperature_2m_historic"]
    #         temperature_forecast = forecast_weather_data["temperature_2m_forecast"]
    #         shortwave_radiation_historic = historic_weather_data["shortwave_radiation_historic"]
    #         shortwave_radiation_forecast = forecast_weather_data["shortwave_radiation_forecast"]
    #         cloud_cover_historic = historic_weather_data["cloud_cover_historic"]
    #         cloud_cover_forecast = forecast_weather_data["cloud_cover_forecast"]

    #         combined_data = pd.concat(
    #             [net_load_demand, temperature_historic, temperature_forecast, shortwave_radiation_historic, shortwave_radiation_forecast, cloud_cover_historic, cloud_cover_forecast], axis=1
    #         ).dropna()
    #         combined_data = combined_data.loc[prev_date:end_date]
    #         # combined_data_daytime = combined_data.between_time("06:00", "20:00")

    #         train_stats = self.get_train_stats(train_stats_path, feeder_filesave_name)
    #         print(train_stats)

    #         # normalized_data = self.minmax_scale(combined_data_daytime, train_stats["Min"], train_stats["Max"])
    #         normalized_data = self.minmax_scale(combined_data, train_stats["Min"], train_stats["Max"])
    #         print(normalized_data.describe())

    #         # denormalized_data = minmax_inverse_scale(normalized_data, train_stats['Min'], train_stats['Max'])
    #         # print(denormalized_data.describe())
    #         print(normalized_data)
    #         dates_index = self.get_unique_dates_from_hourly_data(normalized_data)
    #         print(dates_index)
    #         day_of_week = self.get_one_hot_day_of_week(dates_index)
    #         day_of_week = self.add_is_holiday_column_to_one_hot_day_of_week(day_of_week, barbados_holidays_df)

    #         X, X_LSTM, y_bl, y_cl, cur_dates, prev_dates = self.create_X_y(normalized_data, target_column, hours_in_day, day_of_week)

    #         trained_ann_model_bl = self.get_trained_model_keras(saved_models_path, "ANN_BL", feeder_filesave_name)
    #         trained_ann_model_cl = self.get_trained_model_keras(saved_models_path, "ANN_CL", feeder_filesave_name)
    #         trained_lstm_model_bl = self.get_trained_model_keras(saved_models_path, "LSTM_BL", feeder_filesave_name)
    #         trained_lstm_model_cl = self.get_trained_model_keras(saved_models_path, "LSTM_CL", feeder_filesave_name)
    #         trained_benchmark_model = self.get_trained_model_keras(saved_models_path, "Benchmark", feeder_filesave_name)

    #         adapted_rls_combiner_ann = self.get_saved_rls_combiner(saved_models_path, "RLS_ANN", feeder_filesave_name)
    #         adapted_rls_combiner_lstm = self.get_saved_rls_combiner(saved_models_path, "RLS_LSTM", feeder_filesave_name)
    #         adapted_rls_combiner_final = self.get_saved_rls_combiner(saved_models_path, "RLS_Final", feeder_filesave_name)

    #         y_pred_bl = self.predict_model(trained_ann_model_bl, X)
    #         y_pred_cl = self.predict_model(trained_ann_model_cl, X)
    #         y_pred_bl_LSTM = self.predict_model(trained_lstm_model_bl, X_LSTM)
    #         y_pred_cl_LSTM = self.predict_model(trained_lstm_model_cl, X_LSTM)

    #         y_pred_bl_cl = self.convert_cl_to_bl(y_pred_cl, y_bl, X, hours_in_day)
    #         y_pred_bl_cl_LSTM = self.convert_cl_to_bl(y_pred_cl_LSTM, y_bl, X, hours_in_day)

    #         print(X.shape, X_LSTM.shape, y_bl.shape, y_cl.shape, cur_dates.shape, prev_dates.shape)
    #         print(y_pred_bl.shape, y_pred_cl.shape, y_pred_bl_LSTM.shape, y_pred_cl_LSTM.shape)

    #         y_pred_ann_rls, rls_combiner_ann = self.adapt_and_predict_rls_combiner(y_bl, y_pred_bl, y_pred_bl_cl, hours_in_day, adapted_rls_combiner_ann)
    #         y_pred_lstm_rls, rls_combiner_lstm = self.adapt_and_predict_rls_combiner(y_bl, y_pred_bl_LSTM, y_pred_bl_cl_LSTM, hours_in_day, adapted_rls_combiner_lstm)
    #         y_pred_final_rls, rls_combiner_final = self.adapt_and_predict_rls_combiner(y_bl, y_pred_ann_rls, y_pred_lstm_rls, hours_in_day, adapted_rls_combiner_final)

    #         final_results = pd.DataFrame([y_bl.flatten(), y_pred_ann_rls.flatten(), y_pred_lstm_rls.flatten(), y_pred_final_rls.flatten()]).T
    #         final_results.columns = ["Actual", "ANN_RLS", "LSTM_RLS", "Final_RLS"]
    #         final_results.index = cur_dates.flatten()

    #         print("==============================", final_results.describe())

    #         final_metrics = self.get_metrics(final_results)

    #         final_results = final_results.apply(
    #             lambda x: self.minmax_inverse_scale(x, train_stats.loc[target_column, "Min"], train_stats.loc[target_column, "Max"])
    #         )

    #         px.line(final_results).show()
    #         print(final_metrics)

            # self.save_results(final_results, self.saved_results_path, feeder_filesave_name, is_validation)
            # self.save_metrics(final_metrics, self.saved_metrics_path, feeder_filesave_name, is_validation)

    def batch_forecast_feeders_data_from_trained_models(self, start_date, end_date, is_validation=False):
        prev_date = pd.to_datetime(start_date) - pd.Timedelta(days=1)
        prev_date = prev_date.strftime("%Y-%m-%d")
        feeders_metadata = pd.read_csv(self.feeders_metadata_path)
        weather_utils = WeatherUtils()
        feeders_root_path = self.feeders_root_path
        saved_models_path = self.saved_models_path
        train_stats_path = self.train_stats_path
        hours_in_day = self.hours_in_day
        target_column = self.target_column
        barbados_holidays_df = self.barbados_holidays_df
        threshold = self.threshold
        if is_validation:
            features_folder_name = "Validation_Features"
        else:
            features_folder_name = "Test_Features"

        print(feeders_metadata.shape)

        for i in range(feeders_metadata.shape[0]):
            print("i: ",  i)
            feeder_metadata = feeders_metadata.iloc[i]
            feeder_name = feeder_metadata["FeederName"]
            feeder_data_filename = feeder_metadata["FileName"]
            feeder_filesave_name = feeder_metadata["FileSaveName"]
            feeder_data_path = feeders_root_path + feeder_data_filename
            feeder_data = self.get_raw_data_from_path(feeder_data_path)
            net_load_demand = self.preprocess_raw_data(feeder_data, "NetLoadDemand", threshold)
            latitude = feeder_metadata["Latitude"]
            longitude = feeder_metadata["Longitude"]

            print("========================================")
            print(feeder_name)
            print("========================================")

            historic_weather_data = weather_utils.fetch_historic_data_from_api(latitude, longitude, start_date, end_date)
            forecast_weather_data = weather_utils.fetch_forecast_data_from_api(latitude, longitude, start_date, end_date)

            temperature_historic = historic_weather_data["temperature_2m_historic"]
            temperature_forecast = forecast_weather_data["temperature_2m_forecast"]
            shortwave_radiation_historic = historic_weather_data["shortwave_radiation_historic"]
            shortwave_radiation_forecast = forecast_weather_data["shortwave_radiation_forecast"]
            cloud_cover_historic = historic_weather_data["cloud_cover_historic"]
            cloud_cover_forecast = forecast_weather_data["cloud_cover_forecast"]

            combined_data = pd.concat(
                [net_load_demand, temperature_historic, temperature_forecast, shortwave_radiation_historic, shortwave_radiation_forecast, cloud_cover_historic, cloud_cover_forecast], axis=1
            ).dropna()
            combined_data = combined_data.loc[start_date:end_date]

            if self.daytime_flag:
                combined_data = combined_data.between_time("06:00", "20:00")
            else:
                combined_data = combined_data.between_time("21:00", "05:00")

            print("+++++++++++++++++++++++++++")
            print(combined_data)
            print("+++++++++++++++++++++++++++")

            # combined_data_daytime = combined_data.between_time("06:00", "20:00")
            # combined_data = combined_data_daytime.copy()

            train_stats = self.get_train_stats(train_stats_path, feeder_filesave_name)
            print(train_stats)

            # normalized_data = self.minmax_scale(combined_data_daytime, train_stats["Min"], train_stats["Max"])
            normalized_data = self.minmax_scale(combined_data, train_stats["Min"], train_stats["Max"])
            print(normalized_data.describe())

            # denormalized_data = minmax_inverse_scale(normalized_data, train_stats['Min'], train_stats['Max'])
            # print(denormalized_data.describe())

            dates_index = self.get_unique_dates_from_hourly_data(normalized_data)
            # print(dates_index)
            day_of_week = self.get_one_hot_day_of_week(dates_index)
            day_of_week = self.add_is_holiday_column_to_one_hot_day_of_week(day_of_week, barbados_holidays_df)

            X, X_LSTM, y_bl, y_cl, cur_dates, prev_dates = self.create_X_y(normalized_data, target_column, hours_in_day, day_of_week)
            
            print("X shape: ", X.shape)
            print("X shape: ", X)
            
            X_columns_map = {
                'prev_historic_net_load_demand': 15,
                'prev_historic_temperature': 15,
                'cur_forecasted_temperature': 15,
                'prev_historic_solar_irradiance': 15,
                'cur_forecasted_solar_irradiance': 15,
                'prev_historic_cloud_cover': 15,
                'cur_forecasted_cloud_cover': 15,
                'cur_day_of_week': 7,
                'cur_is_holiday': 1,
            }
            
            features_X = pd.DataFrame(X)
            features_X.columns = [f"{i}_{j}" for i in X_columns_map.keys() for j in range(X_columns_map[i])]
            features_X.index = pd.Series(pd.to_datetime(cur_dates.flatten()).date).unique()
            features_X.index.name = "Date"
            features_X = features_X.round(4)
            
            print(features_X.shape, features_X.columns, features_X.index)
            features_X.to_csv(f"H:/My Drive/Barbados_Forecasting_Tool/Data/Clustering_Data/Daytime/{features_folder_name}/{feeder_filesave_name}_X_Test_Normalized.csv")
            
            continue

            trained_ann_model_bl = self.get_trained_model_keras(saved_models_path, "ANN_BL", feeder_filesave_name)
            trained_ann_model_cl = self.get_trained_model_keras(saved_models_path, "ANN_CL", feeder_filesave_name)
            trained_lstm_model_bl = self.get_trained_model_keras(saved_models_path, "LSTM_BL", feeder_filesave_name)
            trained_lstm_model_cl = self.get_trained_model_keras(saved_models_path, "LSTM_CL", feeder_filesave_name)
            trained_benchmark_model_bl = self.get_trained_model(saved_models_path, "Benchmark_BL", feeder_filesave_name)
            trained_benchmark_model_cl = self.get_trained_model(saved_models_path, "Benchmark_CL", feeder_filesave_name)

            adapted_rls_combiner_ann = self.get_saved_rls_combiner(saved_models_path, "RLS_ANN", feeder_filesave_name)
            adapted_rls_combiner_lstm = self.get_saved_rls_combiner(saved_models_path, "RLS_LSTM", feeder_filesave_name)
            adapted_rls_combiner_final = self.get_saved_rls_combiner(saved_models_path, "RLS_Final", feeder_filesave_name)

            y_pred_bl = self.predict_model(trained_ann_model_bl, X)
            y_pred_cl = self.predict_model(trained_ann_model_cl, X)
            y_pred_bl_LSTM = self.predict_model(trained_lstm_model_bl, X_LSTM)
            y_pred_cl_LSTM = self.predict_model(trained_lstm_model_cl, X_LSTM)
            y_pred_bl_benchmark = self.predict_model(trained_benchmark_model_bl, X)
            y_pred_cl_benchmark = self.predict_model(trained_benchmark_model_cl, X)

            y_pred_bl_cl = self.convert_cl_to_bl(y_pred_cl, y_bl, X, hours_in_day)
            y_pred_bl_cl_LSTM = self.convert_cl_to_bl(y_pred_cl_LSTM, y_bl, X, hours_in_day)
            y_pred_bl_cl_benchmark = self.convert_cl_to_bl(y_pred_cl_benchmark, y_bl, X, hours_in_day)

            print(X.shape, X_LSTM.shape, y_bl.shape, y_cl.shape, cur_dates.shape, prev_dates.shape)
            print(y_pred_bl.shape, y_pred_cl.shape, y_pred_bl_LSTM.shape, y_pred_cl_LSTM.shape, y_pred_bl_benchmark.shape, y_pred_cl_benchmark.shape)

            y_pred_ann_rls, rls_combiner_ann = self.adapt_and_predict_rls_combiner(y_bl, y_pred_bl, y_pred_bl_cl, hours_in_day, adapted_rls_combiner_ann)
            y_pred_lstm_rls, rls_combiner_lstm = self.adapt_and_predict_rls_combiner(y_bl, y_pred_bl_LSTM, y_pred_bl_cl_LSTM, hours_in_day, adapted_rls_combiner_lstm)
            y_pred_final_rls, rls_combiner_final = self.adapt_and_predict_rls_combiner(y_bl, y_pred_ann_rls, y_pred_lstm_rls, hours_in_day, adapted_rls_combiner_final)

            final_results = pd.DataFrame([y_bl.flatten(), y_pred_ann_rls.flatten(), y_pred_lstm_rls.flatten(), y_pred_final_rls.flatten(), y_pred_bl_benchmark.flatten()]).T
            final_results.columns = ["Actual", "ANN_RLS", "LSTM_RLS", "Final_RLS", "Benchmark"]
            final_results.index = cur_dates.flatten()

            final_metrics = self.get_metrics(final_results)

            final_results = final_results.apply(
                lambda x: self.minmax_inverse_scale(x, train_stats.loc[target_column, "Min"], train_stats.loc[target_column, "Max"])
            )

            self.save_results(final_results, self.saved_results_path, feeder_filesave_name, is_validation)
            self.save_metrics(final_metrics, self.saved_metrics_path, feeder_filesave_name, is_validation)

            # return final_results

    def get_stats(self, data):
        mean = data.mean()
        std = data.std()
        min = data.min()
        max = data.max()

        return mean, std, min, max

    def build_models_and_train_feeders_data(self, start_date, end_date):
        feeders_metadata = pd.read_csv(self.feeders_metadata_path)
        weather_utils = WeatherUtils()
        feeders_root_path = self.feeders_root_path
        saved_models_path = self.saved_models_path
        train_stats_path = self.train_stats_path
        hours_in_day = self.hours_in_day
        target_column = self.target_column
        barbados_holidays_df = self.barbados_holidays_df
        threshold = self.threshold

        for i in range(feeders_metadata.shape[0]):
            feeder_metadata = feeders_metadata.iloc[i]
            feeder_name = feeder_metadata["FeederName"]
            feeder_data_filename = feeder_metadata["FileName"]
            feeder_filesave_name = feeder_metadata["FileSaveName"]
            feeder_data_path = feeders_root_path + feeder_data_filename
            feeder_data = self.get_raw_data_from_path(feeder_data_path)
            net_load_demand = self.preprocess_raw_data(feeder_data, "NetLoadDemand", threshold)
            latitude = feeder_metadata["Latitude"]
            longitude = feeder_metadata["Longitude"]

            print("========================================")
            print(feeder_name)
            print("========================================")

            historic_weather_data = weather_utils.fetch_historic_data_from_api(latitude, longitude, start_date, end_date)
            forecast_weather_data = weather_utils.fetch_forecast_data_from_api(latitude, longitude, start_date, end_date)

            temperature_historic = historic_weather_data["temperature_2m_historic"]
            temperature_forecast = forecast_weather_data["temperature_2m_forecast"]
            shortwave_radiation_historic = historic_weather_data["shortwave_radiation_historic"]
            shortwave_radiation_forecast = forecast_weather_data["shortwave_radiation_forecast"]
            cloud_cover_historic = historic_weather_data["cloud_cover_historic"]
            cloud_cover_forecast = forecast_weather_data["cloud_cover_forecast"]

            combined_data = pd.concat(
                [net_load_demand, temperature_historic, temperature_forecast, shortwave_radiation_historic, shortwave_radiation_forecast, cloud_cover_historic, cloud_cover_forecast], axis=1
            ).dropna()

            combined_data = combined_data.loc[start_date:end_date]
            if self.daytime_flag:
                combined_data = combined_data.between_time("06:00", "20:00")
            else:
                combined_data = pd.concat([combined_data.between_time('21:00', '23:00'), combined_data.between_time('00:00', '05:00')]).sort_index()
            #     combined_data_daytime = combined_data.between_time("06:00", "20:00")
            # combined_data = combined_data_daytime.copy()

            print("+++++++++++++++++++++++++++")
            print(combined_data)
            print("+++++++++++++++++++++++++++")

            mean, std, min, max = self.get_stats(combined_data)
            # mean, std, min, max = self.get_stats(combined_data_daytime)

            train_stats = pd.concat([mean, std, min, max], axis=1)
            train_stats.columns = ['Mean', 'Std', 'Min', 'Max']
            os.makedirs(train_stats_path, exist_ok=True)
            train_stats.to_csv(f"{train_stats_path}/{feeder_filesave_name}_train_stats.csv")

            # normalized_data = self.minmax_scale(combined_data_daytime, train_stats["Min"], train_stats["Max"])
            normalized_data = self.minmax_scale(combined_data, train_stats["Min"], train_stats["Max"])
            print(normalized_data.describe())

            # denormalized_data = minmax_inverse_scale(normalized_data, train_stats['Min'], train_stats['Max'])
            # print(denormalized_data.describe())

            dates_index = self.get_unique_dates_from_hourly_data(normalized_data)
            day_of_week = self.get_one_hot_day_of_week(dates_index)
            day_of_week = self.add_is_holiday_column_to_one_hot_day_of_week(day_of_week, barbados_holidays_df)

            X, X_LSTM, y_bl, y_cl, cur_dates, prev_dates = self.create_X_y(normalized_data, target_column, hours_in_day, day_of_week)

            trained_ann_model_bl = self.train_ann_model(X, y_bl, epochs=200)
            trained_ann_model_cl = self.train_ann_model(X, y_cl, epochs=200)
            trained_lstm_model_bl = self.train_lstm_model(X_LSTM, y_bl, epochs=50)
            trained_lstm_model_cl = self.train_lstm_model(X_LSTM, y_cl, epochs=50)
            trained_benchmark_model_bl = self.train_benchmark_model(X, y_bl)
            trained_benchmark_model_cl = self.train_benchmark_model(X, y_cl)

            self.save_trained_model_keras(trained_ann_model_bl, saved_models_path, "ANN_BL", feeder_filesave_name)
            self.save_trained_model_keras(trained_ann_model_cl, saved_models_path, "ANN_CL", feeder_filesave_name)
            self.save_trained_model_keras(trained_lstm_model_bl, saved_models_path, "LSTM_BL", feeder_filesave_name)
            self.save_trained_model_keras(trained_lstm_model_cl, saved_models_path, "LSTM_CL", feeder_filesave_name)
            self.save_trained_model(trained_benchmark_model_bl, saved_models_path, "Benchmark_BL", feeder_filesave_name)
            self.save_trained_model(trained_benchmark_model_cl, saved_models_path, "Benchmark_CL", feeder_filesave_name)

            y_pred_bl = self.predict_model(trained_ann_model_bl, X)
            y_pred_cl = self.predict_model(trained_ann_model_cl, X)
            y_pred_bl_LSTM = self.predict_model(trained_lstm_model_bl, X_LSTM)
            y_pred_cl_LSTM = self.predict_model(trained_lstm_model_cl, X_LSTM)
            y_pred_bl_benchmark = self.predict_model(trained_benchmark_model_bl, X)
            y_pred_cl_benchmark = self.predict_model(trained_benchmark_model_cl, X)

            y_pred_bl_cl = self.convert_cl_to_bl(y_pred_cl, y_bl, X, hours_in_day)
            y_pred_bl_cl_LSTM = self.convert_cl_to_bl(y_pred_cl_LSTM, y_bl, X, hours_in_day)
            y_pred_bl_cl_benchmark = self.convert_cl_to_bl(y_pred_cl_benchmark, y_bl, X, hours_in_day)

            print(X.shape, X_LSTM.shape, y_bl.shape, y_cl.shape, cur_dates.shape, prev_dates.shape)
            print(y_pred_bl.shape, y_pred_cl.shape, y_pred_bl_LSTM.shape, y_pred_cl_LSTM.shape, y_pred_bl_benchmark.shape, y_pred_cl_benchmark.shape)

            y_pred_ann_rls, rls_combiner_ann = self.adapt_and_predict_rls_combiner(y_bl, y_pred_bl, y_pred_bl_cl, hours_in_day)
            y_pred_lstm_rls, rls_combiner_lstm = self.adapt_and_predict_rls_combiner(y_bl, y_pred_bl_LSTM, y_pred_bl_cl_LSTM, hours_in_day)
            y_pred_final_rls, rls_combiner_final = self.adapt_and_predict_rls_combiner(y_bl, y_pred_ann_rls, y_pred_lstm_rls, hours_in_day)

            self.save_rls_combiner(rls_combiner_ann, "RLS_ANN", saved_models_path, feeder_filesave_name)
            self.save_rls_combiner(rls_combiner_lstm, "RLS_LSTM", saved_models_path, feeder_filesave_name)
            self.save_rls_combiner(rls_combiner_final, "RLS_Final", saved_models_path, feeder_filesave_name)

    def __init__(self, daytime_flag=True):
        if daytime_flag:
            self.time_type = "Daytime"
            self.hours_in_day = 15
            self.threshold = 6
        else:
            self.time_type = "Nighttime"
            self.hours_in_day = 9
            self.threshold = 2

        self.daytime_flag = daytime_flag
        self.saved_ann_models_path = f"./../Saved_Models/{self.time_type}/ANN_Saved_Models"
        self.saved_lstm_models_path = f"./../Saved_Models/{self.time_type}/LSTM_Saved_Models"
        self.saved_rls_combiner_models_path = f"./../Saved_Models/{self.time_type}/RLS_Combiner_Saved_Models"
        self.feeders_metadata_path = "./../Data/Filtered_Feeders_Metadata/Final_Selected_Feeders_Data_with_Coordinates.csv"
        self.feeders_root_path = "./../Data/Feeder_Data/"
        self.openmeteo_weather_data_path = "./../Data/Feeder_Weather_Combined_Data/"
        self.filtered_feeders_metadata_file_path = "../Data/Filtered_Feeders_Metadata/Final_Selected_Feeders_Data_with_Coordinates.csv"
        self.weather_data_path = "./../Data/Weather_Data/high_resolution_weather_arch_hall.csv"
        self.saved_models_path = f"./../Saved_Models/{self.time_type}"
        self.saved_results_path = f"./../Results/{self.time_type}"
        self.saved_metrics_path = f"./../Metrics/{self.time_type}"
        self.train_stats_path = f"./../Data/Filtered_Feeders_Metadata/Train_Stats/{self.time_type}"
        self.end_train = "2024-06-16 23:59:59"
        self.end_val = "2024-06-30 23:59:59"
        self.end_test = "2024-07-31 23:59:59"
        self.start_train_date = "2024-01-01"
        self.start_val_date = "2024-06-17"
        self.start_test_date = "2024-07-01"
        self.end_train_date = "2024-06-16"
        self.end_val_date = "2024-06-30"
        self.end_test_date = "2024-07-31"
        self.freq = "h"
        self.overall_saved_results_path = f"./../Results/Overall"
        self.overall_saved_metrics_path = f"./../Metrics/Overall"
        self.daytime_saved_results_path = f"./../Results/Daytime"
        self.daytime_saved_metrics_path = f"./../Metrics/Daytime"
        self.nighttime_saved_results_path = f"./../Results/Nighttime"
        self.nighttime_saved_metrics_path = f"./../Metrics/Nighttime"
        self.daytime_train_stats_path = f"./../Data/Filtered_Feeders_Metadata/Train_Stats/Daytime"
        self.nighttime_train_stats_path = f"./../Data/Filtered_Feeders_Metadata/Train_Stats/Nighttime"

        self.holiday_years = [2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030]
        # self.hours_in_day = 15
        # self.day_time_hours_in_day = 15
        self.target_column = "NetLoadDemand"
        self.barbados_holidays_df = self.get_barbados_holidays_list(self.holiday_years)

    def save_overall_results_and_metrics(self):
      feeders_metadata = pd.read_csv(self.feeders_metadata_path)

      for i in range(feeders_metadata.shape[0]):
          feeder_metadata = feeders_metadata.iloc[i]
          feeder_name = feeder_metadata["FeederName"]
          feeder_data_filename = feeder_metadata["FileName"]
          feeder_filesave_name = feeder_metadata["FileSaveName"]

          daytime_results_path_val = f"{self.daytime_saved_results_path}/{feeder_filesave_name}_Validation_Results.csv"
          nighttime_results_path_val = f"{self.nighttime_saved_results_path}/{feeder_filesave_name}_Validation_Results.csv"
          daytime_results_path_test = f"{self.daytime_saved_results_path}/{feeder_filesave_name}_Test_Results.csv"
          nighttime_results_path_test = f"{self.nighttime_saved_results_path}/{feeder_filesave_name}_Test_Results.csv"

          daytime_train_stats_path = f"{self.daytime_train_stats_path}/{feeder_filesave_name}_train_stats.csv"
          nighttime_train_stats_path = f"{self.nighttime_train_stats_path}/{feeder_filesave_name}_train_stats.csv"

          daytime_train_stats = pd.read_csv(daytime_train_stats_path, index_col=0)
          nighttime_train_stats = pd.read_csv(nighttime_train_stats_path, index_col=0)

          daytime_results_val = pd.read_csv(f"{daytime_results_path_val}", index_col=0)
          nighttime_results_val = pd.read_csv(f"{nighttime_results_path_val}", index_col=0)

          daytime_results_test = pd.read_csv(f"{daytime_results_path_test}", index_col=0)
          nighttime_results_test = pd.read_csv(f"{nighttime_results_path_test}", index_col=0)

          overall_results_val = pd.concat([daytime_results_val, nighttime_results_val]).sort_index()
          overall_results_test = pd.concat([daytime_results_test, nighttime_results_test]).sort_index()

          overall_results_val_normalized = self.minmax_scale(overall_results_val, daytime_train_stats.loc[self.target_column, "Min"], daytime_train_stats.loc[self.target_column, "Max"])
          overall_results_test_normalized = self.minmax_scale(overall_results_test, daytime_train_stats.loc[self.target_column, "Min"], daytime_train_stats.loc[self.target_column, "Max"])

          overall_metrics_val = self.get_metrics(overall_results_val_normalized)
          overall_metrics_test = self.get_metrics(overall_results_test_normalized)

          self.save_results(overall_results_val, self.overall_saved_results_path, feeder_filesave_name, is_validation=True)
          self.save_results(overall_results_test, self.overall_saved_results_path, feeder_filesave_name, is_validation=False)
          self.save_metrics(overall_metrics_val, self.overall_saved_metrics_path, feeder_filesave_name, is_validation=True)
          self.save_metrics(overall_metrics_test, self.overall_saved_metrics_path, feeder_filesave_name, is_validation=False)

# barbados_trainer = ForecasterUtils()
# barbados_trainer.build_models_and_train_feeders_data(barbados_trainer.start_train_date, barbados_trainer.end_train_date)

# daytime_forecaster = ForecasterUtils(daytime_flag=True)
# daytime_forecaster.build_models_and_train_feeders_data(daytime_forecaster.start_train_date, daytime_forecaster.end_train_date)
# daytime_val_results = daytime_forecaster.batch_forecast_feeders_data_from_trained_models(daytime_forecaster.start_val_date, daytime_forecaster.end_val_date, is_validation=True)
# daytime_test_results = daytime_forecaster.batch_forecast_feeders_data_from_trained_models(daytime_forecaster.start_test_date, daytime_forecaster.end_test_date)

# nighttime_forecaster = ForecasterUtils(daytime_flag=False)
# nighttime_forecaster.build_models_and_train_feeders_data(nighttime_forecaster.start_train_date, nighttime_forecaster.end_train_date)
# nighttime_val_results = nighttime_forecaster.batch_forecast_feeders_data_from_trained_models(nighttime_forecaster.start_val_date, nighttime_forecaster.end_val_date, is_validation=True)
# nighttime_test_results = nighttime_forecaster.batch_forecast_feeders_data_from_trained_models(nighttime_forecaster.start_test_date, nighttime_forecaster.end_test_date)

# overall_results_utils = ForecasterUtils()
# overall_results_utils.save_overall_results_and_metrics()

# %%
daytime_forecaster = ForecasterUtils(daytime_flag=True)
# daytime_forecaster.build_models_and_train_feeders_data(daytime_forecaster.start_train_date, daytime_forecaster.end_train_date)
daytime_val_results = daytime_forecaster.batch_forecast_feeders_data_from_trained_models(daytime_forecaster.start_val_date, daytime_forecaster.end_val_date, is_validation=True)
daytime_test_results = daytime_forecaster.batch_forecast_feeders_data_from_trained_models(daytime_forecaster.start_test_date, daytime_forecaster.end_test_date)
# Out:
# (12, 10)
# i:  0
# Removing Nan Values - Total Dropped Days:  3
# Removing Incomplete Days - Total Dropped Days:  0
# ========================================
# Arch Hall
# ========================================
# Coordinates 13.181018829345703°N -59.56243896484375°E
# Elevation 114.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569ED510>
# Coordinates 13.125°N -59.625°E
# Elevation 114.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569EC970>
# +++++++++++++++++++++++++++
#                      NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# 2024-06-17 06:00:00        6022.60                    25.20                    26.33                          7.00                         10.00                 77.00                 29.00
# 2024-06-17 07:00:00        5103.11                    26.40                    26.93                        121.00                        141.00                 64.00                 50.00
# 2024-06-17 08:00:00        2709.24                    27.75                    27.98                        321.00                        327.00                 98.00                 41.00
# 2024-06-17 09:00:00        1108.69                    29.45                    28.73                        542.00                        533.00                 26.00                 47.00
# 2024-06-17 10:00:00         731.59                    29.85                    29.38                        650.00                        708.00                 40.00                 42.00
# ...                            ...                      ...                      ...                           ...                           ...                   ...                   ...
# 2024-06-30 16:00:00        3177.22                    29.15                    29.68                        424.00                        560.00                 43.00                 72.00
# 2024-06-30 17:00:00        4781.42                    27.30                    28.48                        301.00                        268.00                 94.00                 80.00
# 2024-06-30 18:00:00        6139.78                    26.40                    27.78                        116.00                         97.00                100.00                100.00
# 2024-06-30 19:00:00        7002.49                    26.05                    27.43                          7.00                          7.00                100.00                100.00
# 2024-06-30 20:00:00        8319.03                    25.35                    27.13                          0.00                          0.00                100.00                100.00
#
# [210 rows x 7 columns]
# +++++++++++++++++++++++++++
#                                 Mean     Std      Min      Max
# NetLoadDemand                3037.37 3151.18 -4721.06 10984.23
# temperature_2m_historic        27.78    1.94    22.30    32.40
# temperature_2m_forecast        27.90    1.56    24.08    31.73
# shortwave_radiation_historic  400.14  322.29     0.00  1026.00
# shortwave_radiation_forecast  404.40  321.86     0.00   987.00
# cloud_cover_historic           53.33   33.59     0.00   100.00
# cloud_cover_forecast           60.47   22.66     0.00   100.00
#        NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# count         210.00                   210.00                   210.00                        210.00                        210.00                210.00                210.00
# mean            0.47                     0.61                     0.60                          0.41                          0.43                  0.65                  0.71
# std             0.23                     0.17                     0.15                          0.31                          0.32                  0.34                  0.23
# min             0.03                     0.20                     0.28                          0.00                          0.00                  0.00                  0.04
# 25%             0.27                     0.48                     0.47                          0.11                          0.11                  0.34                  0.52
# 50%             0.48                     0.64                     0.61                          0.43                          0.46                  0.68                  0.69
# 75%             0.67                     0.75                     0.73                          0.69                          0.73                  1.00                  0.98
# max             0.83                     0.87                     0.93                          0.92                          0.93                  1.00                  1.00
# Hours:  15
# Daytime Flag:  True
# Hours in day:  15
# 2024-06-18 06:00:00
# ALERT: Current: 2024-06-18 06:00:00 to 2024-06-18 20:00:00, Previous: 2024-06-17 06:00:00 to 2024-06-17 20:00:00
# 2024-06-19 06:00:00
# ALERT: Current: 2024-06-19 06:00:00 to 2024-06-19 20:00:00, Previous: 2024-06-18 06:00:00 to 2024-06-18 20:00:00
# 2024-06-20 06:00:00
# ALERT: Current: 2024-06-20 06:00:00 to 2024-06-20 20:00:00, Previous: 2024-06-19 06:00:00 to 2024-06-19 20:00:00
# 2024-06-21 06:00:00
# ALERT: Current: 2024-06-21 06:00:00 to 2024-06-21 20:00:00, Previous: 2024-06-20 06:00:00 to 2024-06-20 20:00:00
# 2024-06-22 06:00:00
# ALERT: Current: 2024-06-22 06:00:00 to 2024-06-22 20:00:00, Previous: 2024-06-21 06:00:00 to 2024-06-21 20:00:00
# 2024-06-23 06:00:00
# ALERT: Current: 2024-06-23 06:00:00 to 2024-06-23 20:00:00, Previous: 2024-06-22 06:00:00 to 2024-06-22 20:00:00
# 2024-06-24 06:00:00
# ALERT: Current: 2024-06-24 06:00:00 to 2024-06-24 20:00:00, Previous: 2024-06-23 06:00:00 to 2024-06-23 20:00:00
# 2024-06-25 06:00:00
# ALERT: Current: 2024-06-25 06:00:00 to 2024-06-25 20:00:00, Previous: 2024-06-24 06:00:00 to 2024-06-24 20:00:00
# 2024-06-26 06:00:00
# ALERT: Current: 2024-06-26 06:00:00 to 2024-06-26 20:00:00, Previous: 2024-06-25 06:00:00 to 2024-06-25 20:00:00
# 2024-06-27 06:00:00
# ALERT: Current: 2024-06-27 06:00:00 to 2024-06-27 20:00:00, Previous: 2024-06-26 06:00:00 to 2024-06-26 20:00:00
# 2024-06-28 06:00:00
# ALERT: Current: 2024-06-28 06:00:00 to 2024-06-28 20:00:00, Previous: 2024-06-27 06:00:00 to 2024-06-27 20:00:00
# 2024-06-29 06:00:00
# ALERT: Current: 2024-06-29 06:00:00 to 2024-06-29 20:00:00, Previous: 2024-06-28 06:00:00 to 2024-06-28 20:00:00
# 2024-06-30 06:00:00
# ALERT: Current: 2024-06-30 06:00:00 to 2024-06-30 20:00:00, Previous: 2024-06-29 06:00:00 to 2024-06-29 20:00:00
# X shape:  (13, 113)
# X shape:  [[0.68407929 0.62553243 0.47310831 ... 0.         0.         0.        ]
#  [0.67748048 0.60097988 0.53674433 ... 0.         0.         0.        ]
#  [0.66974349 0.6384946  0.50587818 ... 0.         0.         0.        ]
#  ...
#  [0.67899557 0.65724631 0.544272   ... 0.         0.         0.        ]
#  [0.73603543 0.66144966 0.55849423 ... 1.         0.         0.        ]
#  [0.67015148 0.59306811 0.48755149 ... 0.         1.         0.        ]]
# (13, 113) Index(['prev_historic_net_load_demand_0', 'prev_historic_net_load_demand_1', 'prev_historic_net_load_demand_2', 'prev_historic_net_load_demand_3', 'prev_historic_net_load_demand_4', 'prev_historic_net_load_demand_5', 'prev_historic_net_load_demand_6', 'prev_historic_net_load_demand_7', 'prev_historic_net_load_demand_8', 'prev_historic_net_load_demand_9',
#        ...
#        'cur_forecasted_cloud_cover_13', 'cur_forecasted_cloud_cover_14', 'cur_day_of_week_0', 'cur_day_of_week_1', 'cur_day_of_week_2', 'cur_day_of_week_3', 'cur_day_of_week_4', 'cur_day_of_week_5', 'cur_day_of_week_6', 'cur_is_holiday_0'], dtype='object', length=113) Index([2024-06-18, 2024-06-19, 2024-06-20, 2024-06-21, 2024-06-22, 2024-06-23, 2024-06-24, 2024-06-25, 2024-06-26, 2024-06-27, 2024-06-28, 2024-06-29, 2024-06-30], dtype='object', name='Date')
# i:  1
# Removing Nan Values - Total Dropped Days:  2
# Removing Incomplete Days - Total Dropped Days:  0
# ========================================
# Chapel Street
# ========================================
# Coordinates 13.11072063446045°N -59.590179443359375°E
# Elevation 6.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569EE2F0>
# Coordinates 13.125°N -59.625°E
# Elevation 6.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569EEE90>
# +++++++++++++++++++++++++++
#                      NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# 2024-06-17 06:00:00         380.00                    26.15                    27.03                          7.00                         10.00                 77.00                 29.00
# 2024-06-17 07:00:00         570.00                    27.45                    27.63                        122.00                        141.00                 54.00                 50.00
# 2024-06-17 08:00:00         952.00                    28.55                    28.68                        313.00                        327.00                 99.00                 41.00
# 2024-06-17 09:00:00        1245.00                    30.15                    29.43                        538.00                        533.00                 27.00                 47.00
# 2024-06-17 10:00:00        1404.00                    30.55                    30.08                        656.00                        708.00                 44.00                 42.00
# ...                            ...                      ...                      ...                           ...                           ...                   ...                   ...
# 2024-06-30 16:00:00         345.00                    30.00                    30.38                        432.00                        560.00                 40.00                 72.00
# 2024-06-30 17:00:00         324.00                    28.15                    29.18                        304.00                        268.00                 80.00                 80.00
# 2024-06-30 18:00:00         320.00                    27.35                    28.48                        116.00                         97.00                100.00                100.00
# 2024-06-30 19:00:00         312.00                    26.90                    28.13                          7.00                          7.00                100.00                100.00
# 2024-06-30 20:00:00         312.00                    26.40                    27.83                          0.00                          0.00                100.00                100.00
#
# [210 rows x 7 columns]
# +++++++++++++++++++++++++++
#                                Mean    Std    Min     Max
# NetLoadDemand                914.80 419.45 264.00 1572.00
# temperature_2m_historic       28.71   1.93  23.30   33.20
# temperature_2m_forecast       28.61   1.56  24.78   32.43
# shortwave_radiation_historic 402.00 323.76   0.00 1022.00
# shortwave_radiation_forecast 404.57 322.15   0.00  987.00
# cloud_cover_historic          52.39  34.35   0.00  100.00
# cloud_cover_forecast          60.31  22.73   0.00  100.00
#        NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# count         210.00                   210.00                   210.00                        210.00                        210.00                210.00                210.00
# mean            0.58                     0.61                     0.60                          0.41                          0.43                  0.63                  0.71
# std             0.35                     0.17                     0.15                          0.31                          0.32                  0.35                  0.23
# min             0.03                     0.19                     0.28                          0.00                          0.00                  0.00                  0.04
# 25%             0.21                     0.47                     0.47                          0.11                          0.11                  0.30                  0.52
# 50%             0.69                     0.64                     0.61                          0.43                          0.46                  0.67                  0.69
# 75%             0.93                     0.76                     0.73                          0.70                          0.73                  1.00                  0.98
# max             1.02                     0.91                     0.93                          0.92                          0.93                  1.00                  1.00
# Hours:  15
# Daytime Flag:  True
# Hours in day:  15
# 2024-06-18 06:00:00
# ALERT: Current: 2024-06-18 06:00:00 to 2024-06-18 20:00:00, Previous: 2024-06-17 06:00:00 to 2024-06-17 20:00:00
# 2024-06-19 06:00:00
# ALERT: Current: 2024-06-19 06:00:00 to 2024-06-19 20:00:00, Previous: 2024-06-18 06:00:00 to 2024-06-18 20:00:00
# 2024-06-20 06:00:00
# ALERT: Current: 2024-06-20 06:00:00 to 2024-06-20 20:00:00, Previous: 2024-06-19 06:00:00 to 2024-06-19 20:00:00
# 2024-06-21 06:00:00
# ALERT: Current: 2024-06-21 06:00:00 to 2024-06-21 20:00:00, Previous: 2024-06-20 06:00:00 to 2024-06-20 20:00:00
# 2024-06-22 06:00:00
# ALERT: Current: 2024-06-22 06:00:00 to 2024-06-22 20:00:00, Previous: 2024-06-21 06:00:00 to 2024-06-21 20:00:00
# 2024-06-23 06:00:00
# ALERT: Current: 2024-06-23 06:00:00 to 2024-06-23 20:00:00, Previous: 2024-06-22 06:00:00 to 2024-06-22 20:00:00
# 2024-06-24 06:00:00
# ALERT: Current: 2024-06-24 06:00:00 to 2024-06-24 20:00:00, Previous: 2024-06-23 06:00:00 to 2024-06-23 20:00:00
# 2024-06-25 06:00:00
# ALERT: Current: 2024-06-25 06:00:00 to 2024-06-25 20:00:00, Previous: 2024-06-24 06:00:00 to 2024-06-24 20:00:00
# 2024-06-26 06:00:00
# ALERT: Current: 2024-06-26 06:00:00 to 2024-06-26 20:00:00, Previous: 2024-06-25 06:00:00 to 2024-06-25 20:00:00
# 2024-06-27 06:00:00
# ALERT: Current: 2024-06-27 06:00:00 to 2024-06-27 20:00:00, Previous: 2024-06-26 06:00:00 to 2024-06-26 20:00:00
# 2024-06-28 06:00:00
# ALERT: Current: 2024-06-28 06:00:00 to 2024-06-28 20:00:00, Previous: 2024-06-27 06:00:00 to 2024-06-27 20:00:00
# 2024-06-29 06:00:00
# ALERT: Current: 2024-06-29 06:00:00 to 2024-06-29 20:00:00, Previous: 2024-06-28 06:00:00 to 2024-06-28 20:00:00
# 2024-06-30 06:00:00
# ALERT: Current: 2024-06-30 06:00:00 to 2024-06-30 20:00:00, Previous: 2024-06-29 06:00:00 to 2024-06-29 20:00:00
# X shape:  (13, 113)
# X shape:  [[0.08868502 0.23394495 0.52599388 ... 0.         0.         0.        ]
#  [0.0795107  0.26605505 0.57798165 ... 0.         0.         0.        ]
#  [0.08256881 0.28899083 0.50229358 ... 0.         0.         0.        ]
#  ...
#  [0.10091743 0.21284404 0.53211009 ... 0.         0.         0.        ]
#  [0.10091743 0.28256881 0.57186544 ... 1.         0.         0.        ]
#  [0.10397554 0.18960245 0.32110092 ... 0.         1.         0.        ]]
# (13, 113) Index(['prev_historic_net_load_demand_0', 'prev_historic_net_load_demand_1', 'prev_historic_net_load_demand_2', 'prev_historic_net_load_demand_3', 'prev_historic_net_load_demand_4', 'prev_historic_net_load_demand_5', 'prev_historic_net_load_demand_6', 'prev_historic_net_load_demand_7', 'prev_historic_net_load_demand_8', 'prev_historic_net_load_demand_9',
#        ...
#        'cur_forecasted_cloud_cover_13', 'cur_forecasted_cloud_cover_14', 'cur_day_of_week_0', 'cur_day_of_week_1', 'cur_day_of_week_2', 'cur_day_of_week_3', 'cur_day_of_week_4', 'cur_day_of_week_5', 'cur_day_of_week_6', 'cur_is_holiday_0'], dtype='object', length=113) Index([2024-06-18, 2024-06-19, 2024-06-20, 2024-06-21, 2024-06-22, 2024-06-23, 2024-06-24, 2024-06-25, 2024-06-26, 2024-06-27, 2024-06-28, 2024-06-29, 2024-06-30], dtype='object', name='Date')
# i:  2
# Removing Nan Values - Total Dropped Days:  2
# Removing Incomplete Days - Total Dropped Days:  0
# ========================================
# Dukes
# ========================================
# Coordinates 13.181018829345703°N -59.56243896484375°E
# Elevation 249.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569EEEF0>
# Coordinates 13.25°N -59.625°E
# Elevation 249.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569EEE60>
# +++++++++++++++++++++++++++
#                      NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# 2024-06-17 06:00:00        1824.25                    24.32                    25.16                          7.00                          9.00                 77.00                 50.00
# 2024-06-17 07:00:00        1779.40                    25.52                    25.91                        121.00                        132.00                 64.00                 56.00
# 2024-06-17 08:00:00        1276.08                    26.88                    27.21                        321.00                        331.00                 98.00                 46.00
# 2024-06-17 09:00:00         912.92                    28.57                    28.01                        542.00                        523.00                 26.00                 69.00
# 2024-06-17 10:00:00         603.33                    28.98                    28.81                        650.00                        675.00                 40.00                 64.00
# ...                            ...                      ...                      ...                           ...                           ...                   ...                   ...
# 2024-06-30 16:00:00        1229.75                    28.27                    28.51                        424.00                        499.00                 43.00                 94.00
# 2024-06-30 17:00:00        1616.60                    26.42                    27.46                        301.00                        262.00                 94.00                 98.00
# 2024-06-30 18:00:00        1753.50                    25.52                    26.61                        116.00                        103.00                100.00                 96.00
# 2024-06-30 19:00:00        2070.44                    25.17                    26.16                          7.00                          6.00                100.00                100.00
# 2024-06-30 20:00:00        2481.10                    24.48                    26.16                          0.00                          0.00                100.00                100.00
#
# [210 rows x 7 columns]
# +++++++++++++++++++++++++++
#                                 Mean    Std     Min     Max
# NetLoadDemand                1241.52 646.49 -300.83 4017.22
# temperature_2m_historic        26.91   1.94   21.42   31.52
# temperature_2m_forecast        26.94   1.74   22.31   31.46
# shortwave_radiation_historic  399.68 321.85    0.00 1026.00
# shortwave_radiation_forecast  398.44 318.55    0.00  986.00
# cloud_cover_historic           53.16  33.58    0.00  100.00
# cloud_cover_forecast           65.08  20.39    0.00  100.00
#        NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# count         210.00                   210.00                   210.00                        210.00                        210.00                210.00                210.00
# mean            0.34                     0.61                     0.58                          0.41                          0.42                  0.65                  0.74
# std             0.15                     0.17                     0.13                          0.31                          0.32                  0.34                  0.20
# min             0.07                     0.20                     0.31                          0.00                          0.00                  0.00                  0.23
# 25%             0.21                     0.48                     0.45                          0.11                          0.11                  0.34                  0.57
# 50%             0.34                     0.64                     0.58                          0.43                          0.45                  0.68                  0.73
# 75%             0.48                     0.75                     0.68                          0.69                          0.72                  1.00                  0.95
# max             0.64                     0.87                     0.85                          0.92                          0.94                  1.00                  1.00
# Hours:  15
# Daytime Flag:  True
# Hours in day:  15
# 2024-06-18 06:00:00
# ALERT: Current: 2024-06-18 06:00:00 to 2024-06-18 20:00:00, Previous: 2024-06-17 06:00:00 to 2024-06-17 20:00:00
# 2024-06-19 06:00:00
# ALERT: Current: 2024-06-19 06:00:00 to 2024-06-19 20:00:00, Previous: 2024-06-18 06:00:00 to 2024-06-18 20:00:00
# 2024-06-20 06:00:00
# ALERT: Current: 2024-06-20 06:00:00 to 2024-06-20 20:00:00, Previous: 2024-06-19 06:00:00 to 2024-06-19 20:00:00
# 2024-06-21 06:00:00
# ALERT: Current: 2024-06-21 06:00:00 to 2024-06-21 20:00:00, Previous: 2024-06-20 06:00:00 to 2024-06-20 20:00:00
# 2024-06-22 06:00:00
# ALERT: Current: 2024-06-22 06:00:00 to 2024-06-22 20:00:00, Previous: 2024-06-21 06:00:00 to 2024-06-21 20:00:00
# 2024-06-23 06:00:00
# ALERT: Current: 2024-06-23 06:00:00 to 2024-06-23 20:00:00, Previous: 2024-06-22 06:00:00 to 2024-06-22 20:00:00
# 2024-06-24 06:00:00
# ALERT: Current: 2024-06-24 06:00:00 to 2024-06-24 20:00:00, Previous: 2024-06-23 06:00:00 to 2024-06-23 20:00:00
# 2024-06-25 06:00:00
# ALERT: Current: 2024-06-25 06:00:00 to 2024-06-25 20:00:00, Previous: 2024-06-24 06:00:00 to 2024-06-24 20:00:00
# 2024-06-26 06:00:00
# ALERT: Current: 2024-06-26 06:00:00 to 2024-06-26 20:00:00, Previous: 2024-06-25 06:00:00 to 2024-06-25 20:00:00
# 2024-06-27 06:00:00
# ALERT: Current: 2024-06-27 06:00:00 to 2024-06-27 20:00:00, Previous: 2024-06-26 06:00:00 to 2024-06-26 20:00:00
# 2024-06-28 06:00:00
# ALERT: Current: 2024-06-28 06:00:00 to 2024-06-28 20:00:00, Previous: 2024-06-27 06:00:00 to 2024-06-27 20:00:00
# 2024-06-29 06:00:00
# ALERT: Current: 2024-06-29 06:00:00 to 2024-06-29 20:00:00, Previous: 2024-06-28 06:00:00 to 2024-06-28 20:00:00
# 2024-06-30 06:00:00
# ALERT: Current: 2024-06-30 06:00:00 to 2024-06-30 20:00:00, Previous: 2024-06-29 06:00:00 to 2024-06-29 20:00:00
# X shape:  (13, 113)
# X shape:  [[0.49213895 0.48175233 0.36519138 ... 0.         0.         0.        ]
#  [0.50211644 0.46717506 0.34955057 ... 0.         0.         0.        ]
#  [0.49967707 0.48614404 0.37217755 ... 0.         0.         0.        ]
#  ...
#  [0.4962496  0.48693985 0.38887102 ... 0.         0.         0.        ]
#  [0.49469467 0.48010807 0.35716307 ... 1.         0.         0.        ]
#  [0.46505169 0.4280476  0.38761274 ... 0.         1.         0.        ]]
# (13, 113) Index(['prev_historic_net_load_demand_0', 'prev_historic_net_load_demand_1', 'prev_historic_net_load_demand_2', 'prev_historic_net_load_demand_3', 'prev_historic_net_load_demand_4', 'prev_historic_net_load_demand_5', 'prev_historic_net_load_demand_6', 'prev_historic_net_load_demand_7', 'prev_historic_net_load_demand_8', 'prev_historic_net_load_demand_9',
#        ...
#        'cur_forecasted_cloud_cover_13', 'cur_forecasted_cloud_cover_14', 'cur_day_of_week_0', 'cur_day_of_week_1', 'cur_day_of_week_2', 'cur_day_of_week_3', 'cur_day_of_week_4', 'cur_day_of_week_5', 'cur_day_of_week_6', 'cur_is_holiday_0'], dtype='object', length=113) Index([2024-06-18, 2024-06-19, 2024-06-20, 2024-06-21, 2024-06-22, 2024-06-23, 2024-06-24, 2024-06-25, 2024-06-26, 2024-06-27, 2024-06-28, 2024-06-29, 2024-06-30], dtype='object', name='Date')
# i:  3
# Removing Nan Values - Total Dropped Days:  3
# Removing Incomplete Days - Total Dropped Days:  0
# ========================================
# Fontabelle 1
# ========================================
# Coordinates 13.11072063446045°N -59.590179443359375°E
# Elevation 6.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569ECF70>
# Coordinates 13.125°N -59.625°E
# Elevation 6.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569ECAF0>
# +++++++++++++++++++++++++++
#                      NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# 2024-06-17 06:00:00          14.00                    26.15                    27.03                          7.00                         10.00                 77.00                 29.00
# 2024-06-17 07:00:00          15.00                    27.45                    27.63                        122.00                        141.00                 54.00                 50.00
# 2024-06-17 08:00:00          17.25                    28.55                    28.68                        313.00                        327.00                 99.00                 41.00
# 2024-06-17 09:00:00          15.33                    30.15                    29.43                        538.00                        533.00                 27.00                 47.00
# 2024-06-17 10:00:00          15.75                    30.55                    30.08                        656.00                        708.00                 44.00                 42.00
# ...                            ...                      ...                      ...                           ...                           ...                   ...                   ...
# 2024-06-30 16:00:00           5.67                    30.00                    30.38                        432.00                        560.00                 40.00                 72.00
# 2024-06-30 17:00:00           7.50                    28.15                    29.18                        304.00                        268.00                 80.00                 80.00
# 2024-06-30 18:00:00          10.50                    27.35                    28.48                        116.00                         97.00                100.00                100.00
# 2024-06-30 19:00:00          10.00                    26.90                    28.13                          7.00                          7.00                100.00                100.00
# 2024-06-30 20:00:00           9.88                    26.40                    27.83                          0.00                          0.00                100.00                100.00
#
# [210 rows x 7 columns]
# +++++++++++++++++++++++++++
#                                Mean    Std   Min     Max
# NetLoadDemand                 14.45   5.46 -2.60   27.67
# temperature_2m_historic       28.71   1.93 23.30   33.20
# temperature_2m_forecast       28.61   1.56 24.78   32.43
# shortwave_radiation_historic 402.00 323.76  0.00 1022.00
# shortwave_radiation_forecast 404.57 322.15  0.00  987.00
# cloud_cover_historic          52.39  34.35  0.00  100.00
# cloud_cover_forecast          60.31  22.73  0.00  100.00
#        NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# count         210.00                   210.00                   210.00                        210.00                        210.00                210.00                210.00
# mean            0.71                     0.61                     0.60                          0.41                          0.43                  0.63                  0.71
# std             0.24                     0.17                     0.15                          0.31                          0.32                  0.35                  0.23
# min             0.14                     0.19                     0.28                          0.00                          0.00                  0.00                  0.04
# 25%             0.58                     0.47                     0.47                          0.11                          0.11                  0.30                  0.52
# 50%             0.72                     0.64                     0.61                          0.43                          0.46                  0.67                  0.69
# 75%             0.90                     0.76                     0.73                          0.70                          0.73                  1.00                  0.98
# max             1.16                     0.91                     0.93                          0.92                          0.93                  1.00                  1.00
# Hours:  15
# Daytime Flag:  True
# Hours in day:  15
# 2024-06-18 06:00:00
# ALERT: Current: 2024-06-18 06:00:00 to 2024-06-18 20:00:00, Previous: 2024-06-17 06:00:00 to 2024-06-17 20:00:00
# 2024-06-19 06:00:00
# ALERT: Current: 2024-06-19 06:00:00 to 2024-06-19 20:00:00, Previous: 2024-06-18 06:00:00 to 2024-06-18 20:00:00
# 2024-06-20 06:00:00
# ALERT: Current: 2024-06-20 06:00:00 to 2024-06-20 20:00:00, Previous: 2024-06-19 06:00:00 to 2024-06-19 20:00:00
# 2024-06-21 06:00:00
# ALERT: Current: 2024-06-21 06:00:00 to 2024-06-21 20:00:00, Previous: 2024-06-20 06:00:00 to 2024-06-20 20:00:00
# 2024-06-22 06:00:00
# ALERT: Current: 2024-06-22 06:00:00 to 2024-06-22 20:00:00, Previous: 2024-06-21 06:00:00 to 2024-06-21 20:00:00
# 2024-06-23 06:00:00
# ALERT: Current: 2024-06-23 06:00:00 to 2024-06-23 20:00:00, Previous: 2024-06-22 06:00:00 to 2024-06-22 20:00:00
# 2024-06-24 06:00:00
# ALERT: Current: 2024-06-24 06:00:00 to 2024-06-24 20:00:00, Previous: 2024-06-23 06:00:00 to 2024-06-23 20:00:00
# 2024-06-25 06:00:00
# ALERT: Current: 2024-06-25 06:00:00 to 2024-06-25 20:00:00, Previous: 2024-06-24 06:00:00 to 2024-06-24 20:00:00
# 2024-06-26 06:00:00
# ALERT: Current: 2024-06-26 06:00:00 to 2024-06-26 20:00:00, Previous: 2024-06-25 06:00:00 to 2024-06-25 20:00:00
# 2024-06-27 06:00:00
# ALERT: Current: 2024-06-27 06:00:00 to 2024-06-27 20:00:00, Previous: 2024-06-26 06:00:00 to 2024-06-26 20:00:00
# 2024-06-28 06:00:00
# ALERT: Current: 2024-06-28 06:00:00 to 2024-06-28 20:00:00, Previous: 2024-06-27 06:00:00 to 2024-06-27 20:00:00
# 2024-06-29 06:00:00
# ALERT: Current: 2024-06-29 06:00:00 to 2024-06-29 20:00:00, Previous: 2024-06-28 06:00:00 to 2024-06-28 20:00:00
# 2024-06-30 06:00:00
# ALERT: Current: 2024-06-30 06:00:00 to 2024-06-30 20:00:00, Previous: 2024-06-29 06:00:00 to 2024-06-29 20:00:00
# X shape:  (13, 113)
# X shape:  [[0.54845815 0.5814978  0.655837   ... 0.         0.         0.        ]
#  [0.61453744 0.59801762 0.66409692 ... 0.         0.         0.        ]
#  [0.59801762 0.66409692 0.64757709 ... 0.         0.         0.        ]
#  ...
#  [0.81277533 0.81277533 0.89537445 ... 0.         0.         0.        ]
#  [0.81277533 0.80451542 0.79625551 ... 1.         0.         0.        ]
#  [0.7907489  0.68061674 0.46585903 ... 0.         1.         0.        ]]
# (13, 113) Index(['prev_historic_net_load_demand_0', 'prev_historic_net_load_demand_1', 'prev_historic_net_load_demand_2', 'prev_historic_net_load_demand_3', 'prev_historic_net_load_demand_4', 'prev_historic_net_load_demand_5', 'prev_historic_net_load_demand_6', 'prev_historic_net_load_demand_7', 'prev_historic_net_load_demand_8', 'prev_historic_net_load_demand_9',
#        ...
#        'cur_forecasted_cloud_cover_13', 'cur_forecasted_cloud_cover_14', 'cur_day_of_week_0', 'cur_day_of_week_1', 'cur_day_of_week_2', 'cur_day_of_week_3', 'cur_day_of_week_4', 'cur_day_of_week_5', 'cur_day_of_week_6', 'cur_is_holiday_0'], dtype='object', length=113) Index([2024-06-18, 2024-06-19, 2024-06-20, 2024-06-21, 2024-06-22, 2024-06-23, 2024-06-24, 2024-06-25, 2024-06-26, 2024-06-27, 2024-06-28, 2024-06-29, 2024-06-30], dtype='object', name='Date')
# i:  4
# Removing Nan Values - Total Dropped Days:  2
# Removing Incomplete Days - Total Dropped Days:  0
# ========================================
# Green Hill
# ========================================
# Coordinates 13.11072063446045°N -59.590179443359375°E
# Elevation 73.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569EE950>
# Coordinates 13.125°N -59.625°E
# Elevation 73.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569ED210>
# +++++++++++++++++++++++++++
#                      NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# 2024-06-17 06:00:00        3143.33                    25.72                    26.59                          7.00                         10.00                 77.00                 29.00
# 2024-06-17 07:00:00        3074.00                    27.02                    27.19                        122.00                        141.00                 54.00                 50.00
# 2024-06-17 08:00:00        2694.08                    28.12                    28.24                        313.00                        327.00                 99.00                 41.00
# 2024-06-17 09:00:00        2206.83                    29.72                    28.99                        538.00                        533.00                 27.00                 47.00
# 2024-06-17 10:00:00        1905.17                    30.12                    29.64                        656.00                        708.00                 44.00                 42.00
# ...                            ...                      ...                      ...                           ...                           ...                   ...                   ...
# 2024-06-30 16:00:00        1206.67                    29.57                    29.94                        432.00                        560.00                 40.00                 72.00
# 2024-06-30 17:00:00        2200.58                    27.72                    28.74                        304.00                        268.00                 80.00                 80.00
# 2024-06-30 18:00:00        2817.75                    26.92                    28.04                        116.00                         97.00                100.00                100.00
# 2024-06-30 19:00:00        3214.25                    26.47                    27.69                          7.00                          7.00                100.00                100.00
# 2024-06-30 20:00:00        3542.75                    25.97                    27.39                          0.00                          0.00                100.00                100.00
#
# [210 rows x 7 columns]
# +++++++++++++++++++++++++++
#                                 Mean     Std      Min     Max
# NetLoadDemand                2115.73 1539.13 -3445.25 5543.33
# temperature_2m_historic        28.28    1.93    22.87   32.77
# temperature_2m_forecast        28.18    1.57    24.34   31.99
# shortwave_radiation_historic  401.46  323.00     0.00 1016.00
# shortwave_radiation_forecast  404.75  322.20     0.00  987.00
# cloud_cover_historic           52.43   34.32     0.00  100.00
# cloud_cover_forecast           60.35   22.74     0.00  100.00
#        NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# count         210.00                   210.00                   210.00                        210.00                        210.00                210.00                210.00
# mean            0.65                     0.61                     0.60                          0.41                          0.43                  0.63                  0.71
# std             0.16                     0.17                     0.15                          0.31                          0.32                  0.35                  0.23
# min             0.24                     0.19                     0.28                          0.00                          0.00                  0.00                  0.04
# 25%             0.55                     0.47                     0.47                          0.11                          0.11                  0.30                  0.52
# 50%             0.68                     0.64                     0.61                          0.43                          0.46                  0.67                  0.69
# 75%             0.76                     0.76                     0.73                          0.71                          0.73                  1.00                  0.98
# max             0.96                     0.91                     0.93                          0.93                          0.93                  1.00                  1.00
# Hours:  15
# Daytime Flag:  True
# Hours in day:  15
# 2024-06-18 06:00:00
# ALERT: Current: 2024-06-18 06:00:00 to 2024-06-18 20:00:00, Previous: 2024-06-17 06:00:00 to 2024-06-17 20:00:00
# 2024-06-19 06:00:00
# ALERT: Current: 2024-06-19 06:00:00 to 2024-06-19 20:00:00, Previous: 2024-06-18 06:00:00 to 2024-06-18 20:00:00
# 2024-06-20 06:00:00
# ALERT: Current: 2024-06-20 06:00:00 to 2024-06-20 20:00:00, Previous: 2024-06-19 06:00:00 to 2024-06-19 20:00:00
# 2024-06-21 06:00:00
# ALERT: Current: 2024-06-21 06:00:00 to 2024-06-21 20:00:00, Previous: 2024-06-20 06:00:00 to 2024-06-20 20:00:00
# 2024-06-22 06:00:00
# ALERT: Current: 2024-06-22 06:00:00 to 2024-06-22 20:00:00, Previous: 2024-06-21 06:00:00 to 2024-06-21 20:00:00
# 2024-06-23 06:00:00
# ALERT: Current: 2024-06-23 06:00:00 to 2024-06-23 20:00:00, Previous: 2024-06-22 06:00:00 to 2024-06-22 20:00:00
# 2024-06-24 06:00:00
# ALERT: Current: 2024-06-24 06:00:00 to 2024-06-24 20:00:00, Previous: 2024-06-23 06:00:00 to 2024-06-23 20:00:00
# 2024-06-25 06:00:00
# ALERT: Current: 2024-06-25 06:00:00 to 2024-06-25 20:00:00, Previous: 2024-06-24 06:00:00 to 2024-06-24 20:00:00
# 2024-06-26 06:00:00
# ALERT: Current: 2024-06-26 06:00:00 to 2024-06-26 20:00:00, Previous: 2024-06-25 06:00:00 to 2024-06-25 20:00:00
# 2024-06-27 06:00:00
# ALERT: Current: 2024-06-27 06:00:00 to 2024-06-27 20:00:00, Previous: 2024-06-26 06:00:00 to 2024-06-26 20:00:00
# 2024-06-28 06:00:00
# ALERT: Current: 2024-06-28 06:00:00 to 2024-06-28 20:00:00, Previous: 2024-06-27 06:00:00 to 2024-06-27 20:00:00
# 2024-06-29 06:00:00
# ALERT: Current: 2024-06-29 06:00:00 to 2024-06-29 20:00:00, Previous: 2024-06-28 06:00:00 to 2024-06-28 20:00:00
# 2024-06-30 06:00:00
# ALERT: Current: 2024-06-30 06:00:00 to 2024-06-30 20:00:00, Previous: 2024-06-29 06:00:00 to 2024-06-29 20:00:00
# X shape:  (13, 113)
# X shape:  [[0.73299463 0.72528114 0.68301456 ... 0.         0.         0.        ]
#  [0.75444777 0.70483855 0.71239443 ... 0.         0.         0.        ]
#  [0.75579207 0.7441384  0.68769643 ... 0.         0.         0.        ]
#  ...
#  [0.74729054 0.73546072 0.68269008 ... 0.         0.         0.        ]
#  [0.73208607 0.70649806 0.6526427  ... 1.         0.         0.        ]
#  [0.72828495 0.66908022 0.58112606 ... 0.         1.         0.        ]]
# (13, 113) Index(['prev_historic_net_load_demand_0', 'prev_historic_net_load_demand_1', 'prev_historic_net_load_demand_2', 'prev_historic_net_load_demand_3', 'prev_historic_net_load_demand_4', 'prev_historic_net_load_demand_5', 'prev_historic_net_load_demand_6', 'prev_historic_net_load_demand_7', 'prev_historic_net_load_demand_8', 'prev_historic_net_load_demand_9',
#        ...
#        'cur_forecasted_cloud_cover_13', 'cur_forecasted_cloud_cover_14', 'cur_day_of_week_0', 'cur_day_of_week_1', 'cur_day_of_week_2', 'cur_day_of_week_3', 'cur_day_of_week_4', 'cur_day_of_week_5', 'cur_day_of_week_6', 'cur_is_holiday_0'], dtype='object', length=113) Index([2024-06-18, 2024-06-19, 2024-06-20, 2024-06-21, 2024-06-22, 2024-06-23, 2024-06-24, 2024-06-25, 2024-06-26, 2024-06-27, 2024-06-28, 2024-06-29, 2024-06-30], dtype='object', name='Date')
# i:  5
# Removing Nan Values - Total Dropped Days:  0
# Removing Incomplete Days - Total Dropped Days:  0
# ========================================
# Hanson (Belmont)
# ========================================
# Coordinates 13.181018829345703°N -59.56243896484375°E
# Elevation 321.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569EFF70>
# Coordinates 13.25°N -59.625°E
# Elevation 321.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E569EDFC0>
# +++++++++++++++++++++++++++
#                      NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# 2024-06-17 06:00:00         980.77                    23.86                    24.69                          7.00                          9.00                 77.00                 50.00
# 2024-06-17 07:00:00        1026.47                    25.06                    25.44                        121.00                        132.00                 64.00                 56.00
# 2024-06-17 08:00:00        1138.50                    26.41                    26.74                        321.00                        331.00                 98.00                 46.00
# 2024-06-17 09:00:00        1152.68                    28.11                    27.54                        542.00                        523.00                 26.00                 69.00
# 2024-06-17 10:00:00        1175.14                    28.51                    28.34                        650.00                        675.00                 40.00                 64.00
# ...                            ...                      ...                      ...                           ...                           ...                   ...                   ...
# 2024-06-30 16:00:00        1061.69                    27.81                    28.04                        424.00                        499.00                 43.00                 94.00
# 2024-06-30 17:00:00        1097.36                    25.96                    26.99                        301.00                        262.00                 94.00                 98.00
# 2024-06-30 18:00:00        1101.71                    25.06                    26.14                        116.00                        103.00                100.00                 96.00
# 2024-06-30 19:00:00        1121.65                    24.71                    25.69                          7.00                          6.00                100.00                100.00
# 2024-06-30 20:00:00        1198.01                    24.01                    25.69                          0.00                          0.00                100.00                100.00
#
# [210 rows x 7 columns]
# +++++++++++++++++++++++++++
#                                 Mean    Std    Min     Max
# NetLoadDemand                1046.67 182.62 571.52 2098.49
# temperature_2m_historic        26.45   1.94  20.96   31.06
# temperature_2m_forecast        26.48   1.74  21.84   30.99
# shortwave_radiation_historic  400.46 322.53   0.00 1026.00
# shortwave_radiation_forecast  399.32 319.19   0.00  986.00
# cloud_cover_historic           53.53  33.64   0.00  100.00
# cloud_cover_forecast           64.94  20.38   0.00  100.00
#        NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# count         210.00                   210.00                   210.00                        210.00                        210.00                210.00                210.00
# mean            0.40                     0.61                     0.58                          0.41                          0.42                  0.65                  0.74
# std             0.08                     0.17                     0.13                          0.31                          0.32                  0.34                  0.20
# min             0.13                     0.20                     0.31                          0.00                          0.00                  0.00                  0.23
# 25%             0.33                     0.48                     0.45                          0.11                          0.11                  0.34                  0.57
# 50%             0.42                     0.64                     0.58                          0.43                          0.45                  0.68                  0.73
# 75%             0.46                     0.75                     0.68                          0.69                          0.72                  1.00                  0.95
# max             0.54                     0.87                     0.85                          0.92                          0.94                  1.00                  1.00
# Hours:  15
# Daytime Flag:  True
# Hours in day:  15
# 2024-06-18 06:00:00
# ALERT: Current: 2024-06-18 06:00:00 to 2024-06-18 20:00:00, Previous: 2024-06-17 06:00:00 to 2024-06-17 20:00:00
# 2024-06-19 06:00:00
# ALERT: Current: 2024-06-19 06:00:00 to 2024-06-19 20:00:00, Previous: 2024-06-18 06:00:00 to 2024-06-18 20:00:00
# 2024-06-20 06:00:00
# ALERT: Current: 2024-06-20 06:00:00 to 2024-06-20 20:00:00, Previous: 2024-06-19 06:00:00 to 2024-06-19 20:00:00
# 2024-06-21 06:00:00
# ALERT: Current: 2024-06-21 06:00:00 to 2024-06-21 20:00:00, Previous: 2024-06-20 06:00:00 to 2024-06-20 20:00:00
# 2024-06-22 06:00:00
# ALERT: Current: 2024-06-22 06:00:00 to 2024-06-22 20:00:00, Previous: 2024-06-21 06:00:00 to 2024-06-21 20:00:00
# 2024-06-23 06:00:00
# ALERT: Current: 2024-06-23 06:00:00 to 2024-06-23 20:00:00, Previous: 2024-06-22 06:00:00 to 2024-06-22 20:00:00
# 2024-06-24 06:00:00
# ALERT: Current: 2024-06-24 06:00:00 to 2024-06-24 20:00:00, Previous: 2024-06-23 06:00:00 to 2024-06-23 20:00:00
# 2024-06-25 06:00:00
# ALERT: Current: 2024-06-25 06:00:00 to 2024-06-25 20:00:00, Previous: 2024-06-24 06:00:00 to 2024-06-24 20:00:00
# 2024-06-26 06:00:00
# ALERT: Current: 2024-06-26 06:00:00 to 2024-06-26 20:00:00, Previous: 2024-06-25 06:00:00 to 2024-06-25 20:00:00
# 2024-06-27 06:00:00
# ALERT: Current: 2024-06-27 06:00:00 to 2024-06-27 20:00:00, Previous: 2024-06-26 06:00:00 to 2024-06-26 20:00:00
# 2024-06-28 06:00:00
# ALERT: Current: 2024-06-28 06:00:00 to 2024-06-28 20:00:00, Previous: 2024-06-27 06:00:00 to 2024-06-27 20:00:00
# 2024-06-29 06:00:00
# ALERT: Current: 2024-06-29 06:00:00 to 2024-06-29 20:00:00, Previous: 2024-06-28 06:00:00 to 2024-06-28 20:00:00
# 2024-06-30 06:00:00
# ALERT: Current: 2024-06-30 06:00:00 to 2024-06-30 20:00:00, Previous: 2024-06-29 06:00:00 to 2024-06-29 20:00:00
# X shape:  (13, 113)
# X shape:  [[0.26801382 0.29794612 0.37130934 ... 0.         0.         0.        ]
#  [0.28193918 0.29084921 0.35848054 ... 0.         0.         0.        ]
#  [0.28138574 0.29030816 0.35531851 ... 0.         0.         0.        ]
#  ...
#  [0.29487603 0.3215689  0.38778698 ... 0.         0.         0.        ]
#  [0.27401111 0.29081385 0.33607013 ... 1.         0.         0.        ]
#  [0.30011379 0.28595978 0.30691214 ... 0.         1.         0.        ]]
# ...
# Hours:  15
# Daytime Flag:  True
# Hours in day:  15
# 2024-07-02 06:00:00
# ALERT: Current: 2024-07-02 06:00:00 to 2024-07-02 20:00:00, Previous: 2024-07-01 06:00:00 to 2024-07-01 20:00:00
# 2024-07-03 06:00:00
# ALERT: Current: 2024-07-03 06:00:00 to 2024-07-03 20:00:00, Previous: 2024-07-02 06:00:00 to 2024-07-02 20:00:00
# 2024-07-04 06:00:00
# ALERT: Current: 2024-07-04 06:00:00 to 2024-07-04 20:00:00, Previous: 2024-07-03 06:00:00 to 2024-07-03 20:00:00
# 2024-07-05 06:00:00
# ALERT: Current: 2024-07-05 06:00:00 to 2024-07-05 20:00:00, Previous: 2024-07-04 06:00:00 to 2024-07-04 20:00:00
# 2024-07-06 06:00:00
# ALERT: Current: 2024-07-06 06:00:00 to 2024-07-06 20:00:00, Previous: 2024-07-05 06:00:00 to 2024-07-05 20:00:00
# 2024-07-07 06:00:00
# ALERT: Current: 2024-07-07 06:00:00 to 2024-07-07 20:00:00, Previous: 2024-07-06 06:00:00 to 2024-07-06 20:00:00
# 2024-07-08 06:00:00
# ALERT: Current: 2024-07-08 06:00:00 to 2024-07-08 20:00:00, Previous: 2024-07-07 06:00:00 to 2024-07-07 20:00:00
# 2024-07-09 06:00:00
# ALERT: Current: 2024-07-09 06:00:00 to 2024-07-09 20:00:00, Previous: 2024-07-08 06:00:00 to 2024-07-08 20:00:00
# 2024-07-10 06:00:00
# ALERT: Current: 2024-07-10 06:00:00 to 2024-07-10 20:00:00, Previous: 2024-07-09 06:00:00 to 2024-07-09 20:00:00
# 2024-07-11 06:00:00
# ALERT: Current: 2024-07-11 06:00:00 to 2024-07-11 20:00:00, Previous: 2024-07-10 06:00:00 to 2024-07-10 20:00:00
# 2024-07-12 06:00:00
# ALERT: Current: 2024-07-12 06:00:00 to 2024-07-12 20:00:00, Previous: 2024-07-11 06:00:00 to 2024-07-11 20:00:00
# 2024-07-13 06:00:00
# ALERT: Current: 2024-07-13 06:00:00 to 2024-07-13 20:00:00, Previous: 2024-07-12 06:00:00 to 2024-07-12 20:00:00
# 2024-07-14 06:00:00
# ALERT: Current: 2024-07-14 06:00:00 to 2024-07-14 20:00:00, Previous: 2024-07-13 06:00:00 to 2024-07-13 20:00:00
# 2024-07-15 06:00:00
# ALERT: Current: 2024-07-15 06:00:00 to 2024-07-15 20:00:00, Previous: 2024-07-14 06:00:00 to 2024-07-14 20:00:00
# 2024-07-16 06:00:00
# ALERT: Current: 2024-07-16 06:00:00 to 2024-07-16 20:00:00, Previous: 2024-07-15 06:00:00 to 2024-07-15 20:00:00
# 2024-07-17 06:00:00
# ALERT: Current: 2024-07-17 06:00:00 to 2024-07-17 20:00:00, Previous: 2024-07-16 06:00:00 to 2024-07-16 20:00:00
# 2024-07-18 06:00:00
# ALERT: Current: 2024-07-18 06:00:00 to 2024-07-18 20:00:00, Previous: 2024-07-17 06:00:00 to 2024-07-17 20:00:00
# 2024-07-19 06:00:00
# ALERT: Current: 2024-07-19 06:00:00 to 2024-07-19 20:00:00, Previous: 2024-07-18 06:00:00 to 2024-07-18 20:00:00
# 2024-07-20 06:00:00
# ALERT: Current: 2024-07-20 06:00:00 to 2024-07-20 20:00:00, Previous: 2024-07-19 06:00:00 to 2024-07-19 20:00:00
# 2024-07-21 06:00:00
# ALERT: Current: 2024-07-21 06:00:00 to 2024-07-21 20:00:00, Previous: 2024-07-20 06:00:00 to 2024-07-20 20:00:00
# 2024-07-22 06:00:00
# ALERT: Current: 2024-07-22 06:00:00 to 2024-07-22 20:00:00, Previous: 2024-07-21 06:00:00 to 2024-07-21 20:00:00
# 2024-07-23 06:00:00
# ALERT: Current: 2024-07-23 06:00:00 to 2024-07-23 20:00:00, Previous: 2024-07-22 06:00:00 to 2024-07-22 20:00:00
# 2024-07-24 06:00:00
# ALERT: Current: 2024-07-24 06:00:00 to 2024-07-24 20:00:00, Previous: 2024-07-23 06:00:00 to 2024-07-23 20:00:00
# 2024-07-25 06:00:00
# ALERT: Current: 2024-07-25 06:00:00 to 2024-07-25 20:00:00, Previous: 2024-07-24 06:00:00 to 2024-07-24 20:00:00
# 2024-07-26 06:00:00
# ALERT: Current: 2024-07-26 06:00:00 to 2024-07-26 20:00:00, Previous: 2024-07-25 06:00:00 to 2024-07-25 20:00:00
# 2024-07-27 06:00:00
# ALERT: Current: 2024-07-27 06:00:00 to 2024-07-27 20:00:00, Previous: 2024-07-26 06:00:00 to 2024-07-26 20:00:00
# 2024-07-28 06:00:00
# ALERT: Current: 2024-07-28 06:00:00 to 2024-07-28 20:00:00, Previous: 2024-07-27 06:00:00 to 2024-07-27 20:00:00
# 2024-07-29 06:00:00
# ALERT: Current: 2024-07-29 06:00:00 to 2024-07-29 20:00:00, Previous: 2024-07-28 06:00:00 to 2024-07-28 20:00:00
# 2024-07-30 06:00:00
# ALERT: Current: 2024-07-30 06:00:00 to 2024-07-30 20:00:00, Previous: 2024-07-29 06:00:00 to 2024-07-29 20:00:00
# X shape:  (29, 113)
# X shape:  [[0.02164502 0.00649351 0.00974026 ... 0.         0.         0.        ]
#  [0.02164502 0.04220779 0.21103896 ... 0.         0.         0.        ]
#  [0.05194805 0.07792208 0.16233766 ... 0.         0.         0.        ]
#  ...
#  [0.04545455 0.04761905 0.15844156 ... 0.         1.         0.        ]
#  [0.03030303 0.02597403 0.02597403 ... 0.         0.         0.        ]
#  [0.03246753 0.06493506 0.16558442 ... 0.         0.         0.        ]]
# (29, 113) Index(['prev_historic_net_load_demand_0', 'prev_historic_net_load_demand_1', 'prev_historic_net_load_demand_2', 'prev_historic_net_load_demand_3', 'prev_historic_net_load_demand_4', 'prev_historic_net_load_demand_5', 'prev_historic_net_load_demand_6', 'prev_historic_net_load_demand_7', 'prev_historic_net_load_demand_8', 'prev_historic_net_load_demand_9',
#        ...
#        'cur_forecasted_cloud_cover_13', 'cur_forecasted_cloud_cover_14', 'cur_day_of_week_0', 'cur_day_of_week_1', 'cur_day_of_week_2', 'cur_day_of_week_3', 'cur_day_of_week_4', 'cur_day_of_week_5', 'cur_day_of_week_6', 'cur_is_holiday_0'], dtype='object', length=113) Index([2024-07-02, 2024-07-03, 2024-07-04, 2024-07-05, 2024-07-06, 2024-07-07, 2024-07-08, 2024-07-09, 2024-07-10, 2024-07-11, 2024-07-12, 2024-07-13, 2024-07-14, 2024-07-15, 2024-07-16, 2024-07-17, 2024-07-18, 2024-07-19, 2024-07-20, 2024-07-21, 2024-07-22, 2024-07-23, 2024-07-24, 2024-07-25, 2024-07-26, 2024-07-27, 2024-07-28, 2024-07-29, 2024-07-30], dtype='object', name='Date')
# i:  11
# Removing Nan Values - Total Dropped Days:  2
# Removing Incomplete Days - Total Dropped Days:  0
# ========================================
# Welches
# ========================================
# Coordinates 13.181018829345703°N -59.56243896484375°E
# Elevation 94.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E550138E0>
# Coordinates 13.125°N -59.625°E
# Elevation 94.0 m asl
# Timezone b'America/Barbados' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# <openmeteo_sdk.VariablesWithTime.VariablesWithTime object at 0x0000018E550DB040>
# +++++++++++++++++++++++++++
#                      NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# 2024-07-01 06:00:00         585.00                    25.43                    27.26                          2.00                          2.00                100.00                100.00
# 2024-07-01 07:00:00         542.40                    24.93                    27.16                         29.00                         21.00                100.00                100.00
# 2024-07-01 08:00:00         583.20                    24.98                    27.56                         82.00                         57.00                100.00                100.00
# 2024-07-01 09:00:00         558.00                    26.13                    27.96                         66.00                        209.00                100.00                100.00
# 2024-07-01 10:00:00         513.00                    26.58                    27.91                        115.00                        235.00                100.00                100.00
# ...                            ...                      ...                      ...                           ...                           ...                   ...                   ...
# 2024-07-31 16:00:00         612.60                    29.18                    29.41                        457.00                        524.00                100.00                100.00
# 2024-07-31 17:00:00         695.25                    27.73                    29.06                        195.00                        314.00                 34.00                 98.00
# 2024-07-31 18:00:00         775.50                    27.43                    28.56                        121.00                        121.00                 26.00                 66.00
# 2024-07-31 19:00:00         834.00                    26.68                    28.11                          6.00                          6.00                 25.00                 69.00
# 2024-07-31 20:00:00         814.50                    26.28                    28.06                          0.00                          0.00                 12.00                 30.00
#
# [465 rows x 7 columns]
# +++++++++++++++++++++++++++
#                                Mean    Std     Min     Max
# NetLoadDemand                526.49 253.08 -818.73 3488.00
# temperature_2m_historic       27.92   1.94   22.43   32.53
# temperature_2m_forecast       28.04   1.57   24.21   31.86
# shortwave_radiation_historic 399.79 321.99    0.00 1020.00
# shortwave_radiation_forecast 404.75 322.20    0.00  987.00
# cloud_cover_historic          53.49  33.64    0.00  100.00
# cloud_cover_forecast          60.35  22.74    0.00  100.00
#        NetLoadDemand  temperature_2m_historic  temperature_2m_forecast  shortwave_radiation_historic  shortwave_radiation_forecast  cloud_cover_historic  cloud_cover_forecast
# count         465.00                   465.00                   465.00                        465.00                        465.00                465.00                465.00
# mean            0.32                     0.56                     0.58                          0.38                          0.42                  0.55                  0.65
# std             0.05                     0.17                     0.16                          0.30                          0.32                  0.34                  0.23
# min             0.19                     0.08                     0.20                          0.00                          0.00                  0.00                  0.00
# 25%             0.30                     0.44                     0.46                          0.10                          0.11                  0.24                  0.47
# 50%             0.33                     0.56                     0.58                          0.33                          0.37                  0.49                  0.65
# 75%             0.36                     0.70                     0.71                          0.66                          0.72                  0.96                  0.83
# max             0.42                     0.90                     1.04                          0.92                          0.98                  1.00                  1.00
# Hours:  15
# Daytime Flag:  True
# Hours in day:  15
# 2024-07-02 06:00:00
# ALERT: Current: 2024-07-02 06:00:00 to 2024-07-02 20:00:00, Previous: 2024-07-01 06:00:00 to 2024-07-01 20:00:00
# 2024-07-03 06:00:00
# ALERT: Current: 2024-07-03 06:00:00 to 2024-07-03 20:00:00, Previous: 2024-07-02 06:00:00 to 2024-07-02 20:00:00
# 2024-07-04 06:00:00
# ALERT: Current: 2024-07-04 06:00:00 to 2024-07-04 20:00:00, Previous: 2024-07-03 06:00:00 to 2024-07-03 20:00:00
# 2024-07-05 06:00:00
# ALERT: Current: 2024-07-05 06:00:00 to 2024-07-05 20:00:00, Previous: 2024-07-04 06:00:00 to 2024-07-04 20:00:00
# 2024-07-06 06:00:00
# ALERT: Current: 2024-07-06 06:00:00 to 2024-07-06 20:00:00, Previous: 2024-07-05 06:00:00 to 2024-07-05 20:00:00
# 2024-07-07 06:00:00
# ALERT: Current: 2024-07-07 06:00:00 to 2024-07-07 20:00:00, Previous: 2024-07-06 06:00:00 to 2024-07-06 20:00:00
# 2024-07-08 06:00:00
# ALERT: Current: 2024-07-08 06:00:00 to 2024-07-08 20:00:00, Previous: 2024-07-07 06:00:00 to 2024-07-07 20:00:00
# 2024-07-09 06:00:00
# ALERT: Current: 2024-07-09 06:00:00 to 2024-07-09 20:00:00, Previous: 2024-07-08 06:00:00 to 2024-07-08 20:00:00
# 2024-07-10 06:00:00
# ALERT: Current: 2024-07-10 06:00:00 to 2024-07-10 20:00:00, Previous: 2024-07-09 06:00:00 to 2024-07-09 20:00:00
# 2024-07-11 06:00:00
# ALERT: Current: 2024-07-11 06:00:00 to 2024-07-11 20:00:00, Previous: 2024-07-10 06:00:00 to 2024-07-10 20:00:00
# 2024-07-12 06:00:00
# ALERT: Current: 2024-07-12 06:00:00 to 2024-07-12 20:00:00, Previous: 2024-07-11 06:00:00 to 2024-07-11 20:00:00
# 2024-07-13 06:00:00
# ALERT: Current: 2024-07-13 06:00:00 to 2024-07-13 20:00:00, Previous: 2024-07-12 06:00:00 to 2024-07-12 20:00:00
# 2024-07-14 06:00:00
# ALERT: Current: 2024-07-14 06:00:00 to 2024-07-14 20:00:00, Previous: 2024-07-13 06:00:00 to 2024-07-13 20:00:00
# 2024-07-15 06:00:00
# ALERT: Current: 2024-07-15 06:00:00 to 2024-07-15 20:00:00, Previous: 2024-07-14 06:00:00 to 2024-07-14 20:00:00
# 2024-07-16 06:00:00
# ALERT: Current: 2024-07-16 06:00:00 to 2024-07-16 20:00:00, Previous: 2024-07-15 06:00:00 to 2024-07-15 20:00:00
# 2024-07-17 06:00:00
# ALERT: Current: 2024-07-17 06:00:00 to 2024-07-17 20:00:00, Previous: 2024-07-16 06:00:00 to 2024-07-16 20:00:00
# 2024-07-18 06:00:00
# ALERT: Current: 2024-07-18 06:00:00 to 2024-07-18 20:00:00, Previous: 2024-07-17 06:00:00 to 2024-07-17 20:00:00
# 2024-07-19 06:00:00
# ALERT: Current: 2024-07-19 06:00:00 to 2024-07-19 20:00:00, Previous: 2024-07-18 06:00:00 to 2024-07-18 20:00:00
# 2024-07-20 06:00:00
# ALERT: Current: 2024-07-20 06:00:00 to 2024-07-20 20:00:00, Previous: 2024-07-19 06:00:00 to 2024-07-19 20:00:00
# 2024-07-21 06:00:00
# ALERT: Current: 2024-07-21 06:00:00 to 2024-07-21 20:00:00, Previous: 2024-07-20 06:00:00 to 2024-07-20 20:00:00
# 2024-07-22 06:00:00
# ALERT: Current: 2024-07-22 06:00:00 to 2024-07-22 20:00:00, Previous: 2024-07-21 06:00:00 to 2024-07-21 20:00:00
# 2024-07-23 06:00:00
# ALERT: Current: 2024-07-23 06:00:00 to 2024-07-23 20:00:00, Previous: 2024-07-22 06:00:00 to 2024-07-22 20:00:00
# 2024-07-24 06:00:00
# ALERT: Current: 2024-07-24 06:00:00 to 2024-07-24 20:00:00, Previous: 2024-07-23 06:00:00 to 2024-07-23 20:00:00
# 2024-07-25 06:00:00
# ALERT: Current: 2024-07-25 06:00:00 to 2024-07-25 20:00:00, Previous: 2024-07-24 06:00:00 to 2024-07-24 20:00:00
# 2024-07-26 06:00:00
# ALERT: Current: 2024-07-26 06:00:00 to 2024-07-26 20:00:00, Previous: 2024-07-25 06:00:00 to 2024-07-25 20:00:00
# 2024-07-27 06:00:00
# ALERT: Current: 2024-07-27 06:00:00 to 2024-07-27 20:00:00, Previous: 2024-07-26 06:00:00 to 2024-07-26 20:00:00
# 2024-07-28 06:00:00
# ALERT: Current: 2024-07-28 06:00:00 to 2024-07-28 20:00:00, Previous: 2024-07-27 06:00:00 to 2024-07-27 20:00:00
# 2024-07-29 06:00:00
# ALERT: Current: 2024-07-29 06:00:00 to 2024-07-29 20:00:00, Previous: 2024-07-28 06:00:00 to 2024-07-28 20:00:00
# 2024-07-30 06:00:00
# ALERT: Current: 2024-07-30 06:00:00 to 2024-07-30 20:00:00, Previous: 2024-07-29 06:00:00 to 2024-07-29 20:00:00
# 2024-07-31 06:00:00
# ALERT: Current: 2024-07-31 06:00:00 to 2024-07-31 20:00:00, Previous: 2024-07-30 06:00:00 to 2024-07-30 20:00:00
# X shape:  (30, 113)
# X shape:  [[0.32593828 0.31604678 0.32552033 ... 0.         0.         0.        ]
#  [0.32849242 0.33429729 0.34558196 ... 0.         0.         0.        ]
#  [0.33174315 0.36216068 0.39350699 ... 0.         0.         0.        ]
#  ...
#  [0.32733145 0.31723097 0.28112467 ... 0.         0.         0.        ]
#  [0.33290412 0.34230802 0.34028792 ... 0.         0.         0.        ]
#  [0.32733145 0.32350023 0.33360071 ... 0.         0.         0.        ]]
# (30, 113) Index(['prev_historic_net_load_demand_0', 'prev_historic_net_load_demand_1', 'prev_historic_net_load_demand_2', 'prev_historic_net_load_demand_3', 'prev_historic_net_load_demand_4', 'prev_historic_net_load_demand_5', 'prev_historic_net_load_demand_6', 'prev_historic_net_load_demand_7', 'prev_historic_net_load_demand_8', 'prev_historic_net_load_demand_9',
#        ...
#        'cur_forecasted_cloud_cover_13', 'cur_forecasted_cloud_cover_14', 'cur_day_of_week_0', 'cur_day_of_week_1', 'cur_day_of_week_2', 'cur_day_of_week_3', 'cur_day_of_week_4', 'cur_day_of_week_5', 'cur_day_of_week_6', 'cur_is_holiday_0'], dtype='object', length=113) Index([2024-07-02, 2024-07-03, 2024-07-04, 2024-07-05, 2024-07-06, 2024-07-07, 2024-07-08, 2024-07-09, 2024-07-10, 2024-07-11, 2024-07-12, 2024-07-13, 2024-07-14, 2024-07-15, 2024-07-16, 2024-07-17, 2024-07-18, 2024-07-19, 2024-07-20, 2024-07-21, 2024-07-22, 2024-07-23, 2024-07-24, 2024-07-25, 2024-07-26, 2024-07-27, 2024-07-28, 2024-07-29, 2024-07-30, 2024-07-31], dtype='object', name='Date')
